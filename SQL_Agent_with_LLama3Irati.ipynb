# %%
# !pip install langchain langchain_community ollama

# %%
from langchain_community.llms import Ollama

# %%
llm = Ollama(model = "llama3")#,temperature=0.2)
#qwen2:latest

# %%
for chunk in llm.stream("Hi how are you?"):
    print(chunk, end = "")
# Out:
# I'm just an AI, so I don't have feelings or emotions like humans do. But I'm functioning properly and ready to help with any questions or tasks you may have! How can I assist you today?

# %%
from langchain_community.utilities import SQLDatabase

# %%
#conn_str = "mssql+pyodbc://gg:ostia@minipc/iatest?driver=ODBC+Driver+17+for+SQL+Server"
conn_str = "mssql+pyodbc://gg:ostia@minipc/MSPLITEPRO_v3gg?driver=ODBC+Driver+17+for+SQL+Server"

#conn_str = "mssql+pyodbc://gg:ostia@minipc/korta?driver=ODBC+Driver+17+for+SQL+Server"

q="Cual ha sido las ventas del año pasado a los clientes"
q="Cual ha sido las ventas por año  a los clientes. Muéstrame el resultado en Json"
q="Cuál ha sido el cliente al que más le he vendido"
q="Cuál ha sido el artículo que pasa vendido"
q="Para la empresa con codigo 1, que TIPOREG=CF en la tabla de T_ORDTER. Qué necesidades tengo de de compra para los artículos el 21 de diciembre del 2020"
q="Para la empresa con codigo 1,  Qué necesidades de compra de cantidad de artículos tengo el 21 de diciembre del 2020, Teniendo en cuenta los pedidos que estan en la tabla T_ORDTER con TIPOREG=CF y su stock que esta en la tabla T_STOCKS"
q="Para la empresa con codigo 1,  Qué necesidades de compra de cantidad de artículos tengo el 21 de diciembre del 2020, Teniendo en cuenta los pedidos que estan en la tabla T_ORDTER con TIPOREG=CF, su stock que esta en la tabla T_STOCKS y las ordenes de fabricacion que estan en T_ORDFAB y T_ORDFABM con TIPOREG=F" 
q="Cuántos Clientes hay?"
q="Cuántos Clientes hay con El nombre que contenga 'ELDU' ?"
#q="Cuántas facturas hay"
#db = SQLDatabase.from_uri(conn_str) #("sqlite:///Chinook.db")
#def __init__(
 #       self,
 #       engine: Engine,
 #       schema: Optional[str] = None,
 #       metadata: Optional[MetaData] = None,
 #       ignore_tables: Optional[List[str]] = None,
 #       include_tables: Optional[List[str]] = None,
 #       sample_rows_in_table_info: int = 3,
 #       indexes_in_table_info: bool = False,
 #       custom_table_info: Optional[dict] = None,
 #       view_support: bool = False,
 #       max_string_length: int = 300,
 #       lazy_table_reflection: bool = False,
 #   ):
 #       metadata: Optional[MetaData] = None,
 #       ignore_tables: Optional[List[str]] = None,
 #       include_tables: Optional[List[str]] = None,
 #       sample_rows_in_table_info: int = 3,
 #       indexes_in_table_info: bool = False,
 #       custom_table_info: Optional[dict] = None,
 #       view_support: bool = False,
 #       max_string_length: int = 300,
 #       lazy_table_reflection: bool = False,

#tables=["T_FACTURAS","T_CLIENTES","T_EMPRESA"]
#db111 = SQLDatabase.from_uri(conn_str,include_tables=tables,sample_rows_in_table_info = 0 )
db = SQLDatabase.from_uri(conn_str,sample_rows_in_table_info = 2)#,lazy_table_reflection=True)

#db = SQLDatabase.from_uri("sqlite:///chinook.db", sample_rows_in_table_info = 3)

# %%
db.get_usable_table_names()
# Out:
# ['ALMACEN',
#  'APUNTE',
#  'ARTICULO',
#  'ARTICULOS_ESTRUC',
#  'ASIENTO',
#  'BALANCE',
#  'BALANCEL',
#  'BALANCEL_MASA',
#  'BANCO',
#  'CARACTERISTICA',
#  'CLIENTE',
#  'CLIENTES_USU_LICENCIA',
#  'CONDICIONES_PAGO',
#  'CONFIG_LISNAV',
#  'CONTADOR',
#  'CONTRATO_PAGO',
#  'CONTROL_FEC',
#  'COPIAS',
#  'CUENTA_EMAIL',
#  'CUENTA_EMAIL_CONFIG',
#  'DEF_ARTICULO',
#  'DEF_BALANCE',
#  'DEF_BALANCEL',
#  'DEF_BALANCEL_MASA',
#  'DEF_CONDICIONES_PAGO',
#  'DEF_CONFIG_LISNAV',
#  'DEF_CONTADOR',
#  'DEF_DIVISA',
#  'DEF_DOCUMENTO',
#  'DEF_EMPRESAL',
#  'DEF_ESTILOS_BAL',
#  'DEF_FPAGO',
#  'DEF_GRUPOS_ARTICULO',
#  'DEF_GRUPOS_CLIENTE',
#  'DEF_GRUPOS_DOCUMENTO',
#  'DEF_GRUPOS_DOCUMENTOL',
#  'DEF_GRUPOS_NACION',
#  'DEF_GRUPOS_PROVEEDOR',
#  'DEF_IDIOMA',
#  'DEF_IMPUESTO',
#  'DEF_MASA',
#  'DEF_MASAL',
#  'DEF_MODELOS_NATIVA',
#  'DEF_NACION',
#  'DEF_NATIVA',
#  'DEF_PLANCUENTA',
#  'DEF_PROVINCIA',
#  'DEF_TABLAS_VERSION',
#  'DEF_TIPOPLAN',
#  'DEF_TIPO_IMPUESTO',
#  'DEF_T_EQUIPO',
#  'DEF_T_EQUIPO_REC',
#  'DEF_T_PROYECTO_CALENDARIO',
#  'DEF_T_PROYECTO_CALENDARIO_DIA',
#  'DEF_T_PROYECTO_TIPO',
#  'DEF_T_RECURSO',
#  'DEF_UBICACION',
#  'DEF_UNIDAD',
#  'DEF_USUARIOL',
#  'DESCUENTO',
#  'DIRECCION',
#  'DIVISA',
#  'DOCUMENTO',
#  'EJERCICIO',
#  'EJERCICIOL',
#  'EMPRESA',
#  'EMPRESAL',
#  'EMPRESA_TABLAS_VERSION',
#  'ESTILOS_BAL',
#  'FACTURACION_ORDEN',
#  'FPAGO',
#  'GRUPOS_ARTICULO',
#  'GRUPOS_ARTICULO_CARAC',
#  'GRUPOS_CLIENTE',
#  'GRUPOS_DOCUMENTO',
#  'GRUPOS_DOCUMENTOL',
#  'GRUPOS_NACION',
#  'GRUPOS_PROVEEDOR',
#  'IMPUESTO',
#  'MANDATO',
#  'MASA',
#  'MASAL',
#  'MODELOS_NATIVA',
#  'MOVIMIENTO',
#  'MOVIMIENTOL',
#  'MOVIPROG',
#  'NACION',
#  'NATIVA',
#  'PARTES_GASTO',
#  'PARTES_SESION',
#  'PLANCUENTA',
#  'PROVEEDOR',
#  'PROVINCIA',
#  'REMESA',
#  'SIS_BALANCE',
#  'SIS_BALANCEL',
#  'SIS_BALANCEL_MASA',
#  'SIS_CARACTERISTICA',
#  'SIS_CONFIG_LISNAV',
#  'SIS_COPIA',
#  'SIS_ENVIO_EMAIL',
#  'SIS_ESTILOS_BAL',
#  'SIS_HELP',
#  'SIS_IDIOMA',
#  'SIS_MASA',
#  'SIS_MASAL',
#  'SIS_MODELOS',
#  'SIS_MODELOS_ESTRUC',
#  'SIS_MODELOS_PARAM',
#  'SIS_MODELOS_VAR',
#  'SIS_MODULO',
#  'SIS_MODULO_NACION',
#  'SIS_NOMBRE',
#  'SIS_NOMBREL',
#  'SIS_NOTICIA',
#  'SIS_PUBLICIDAD',
#  'TIPOSDOC',
#  'TIPO_IMPUESTO',
#  'T_ALBARAN',
#  'T_ALBARANL',
#  'T_EQUIPO',
#  'T_EQUIPO_REC',
#  'T_FACTURA',
#  'T_FACTURAL',
#  'T_FACTURA_IMP',
#  'T_FACTURA_VTO',
#  'T_GRECURSO',
#  'T_OFERTA',
#  'T_OFERTAL',
#  'T_ORDTER',
#  'T_ORDTERL',
#  'T_ORDTER_IMP',
#  'T_PROYECTO',
#  'T_PROYECTO_CALENDARIO',
#  'T_PROYECTO_CALENDARIO_DIA',
#  'T_PROYECTO_CALENDARIO_EXCEPCION',
#  'T_PROYECTO_ESTRUC',
#  'T_PROYECTO_LINK',
#  'T_PROYECTO_RECURSO',
#  'T_PROYECTO_RECURSO_UNIT',
#  'T_PROYECTO_TIPO',
#  'T_RECURSO',
#  'T_TARIFASL_CLI',
#  'T_TARIFAS_CLI',
#  'UNIDAD',
#  'USUARIO',
#  'USUARIOL',
#  'USUARIO_SAAS']

# %%
print(db.table_info)
# Out:
# c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain_community\utilities\sql_database.py:316: SAWarning: Cannot correctly sort tables; there are unresolvable cycles between tables "ARTICULO, BANCO, DIVISA, EMPRESA, GRUPOS_NACION, NACION, PROVEEDOR, PROVINCIA, T_RECURSO, USUARIO", which is usually caused by mutually dependent foreign key constraints.  Foreign key constraints involving these tables will not be considered; this warning may raise an error in a future release.
#   metadata_table_names = [tbl.name for tbl in self._metadata.sorted_tables]
# c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain_community\utilities\sql_database.py:328: SAWarning: Cannot correctly sort tables; there are unresolvable cycles between tables "ARTICULO, BANCO, DIVISA, EMPRESA, GRUPOS_NACION, NACION, PROVEEDOR, PROVINCIA, T_RECURSO, USUARIO", which is usually caused by mutually dependent foreign key constraints.  Foreign key constraints involving these tables will not be considered; this warning may raise an error in a future release.
#   for tbl in self._metadata.sorted_tables
# CREATE TABLE [ALMACEN] (
# 	[Id_ALMACEN] INTEGER NOT NULL,
# 	[Id_EMPRESA] INTEGER NULL,
# 	[COD_ALM] NVARCHAR(5) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DENOMI] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_CLIENTE] INTEGER NULL,
# 	[Id_PROVEEDOR] INTEGER NULL,
# 	[INVENTARIO] BIT NOT NULL DEFAULT ((0)),
# 	[FAC_SAL] BIT NOT NULL DEFAULT ((0)),
# 	[FAC_ENT] BIT NOT NULL DEFAULT ((0)),
# 	[CONTACTO] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DIRECC] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CODPOS] NVARCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[LOCALIDAD] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_PROVINCIA] INTEGER NULL,
# 	[Id_PAIS] INTEGER NULL,
# 	[TEL] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[TEL2] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FAX] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[WWW] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[EMAIL1] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[EMAIL2] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[EMAIL3] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[SREFER] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[NREFER] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[BLOQUEO] BIT NOT NULL DEFAULT ((0)),
# 	[FECHAC] DATETIME NULL DEFAULT (getutcdate()),
# 	[FECHAM] DATETIME NULL,
# 	[Id_USUCRE] INTEGER NULL,
# 	[Id_USUMOD] INTEGER NULL,
# 	upsize_ts TIMESTAMP NULL,
# 	[STWF] INTEGER NOT NULL DEFAULT ((0)),
# 	CONSTRAINT [PK_ALMACEN] PRIMARY KEY ([Id_ALMACEN])
# )
#
# /*
# 2 rows from ALMACEN table:
# Id_ALMACEN	Id_EMPRESA	COD_ALM	DENOMI	Id_CLIENTE	Id_PROVEEDOR	INVENTARIO	FAC_SAL	FAC_ENT	CONTACTO	DIRECC	CODPOS	LOCALIDAD	Id_PROVINCIA	Id_PAIS	TEL	TEL2	FAX	WWW	EMAIL1	EMAIL2	EMAIL3	SREFER	NREFER	BLOQUEO	FECHAC	FECHAM	Id_USUCRE	Id_USUMOD	upsize_ts	STWF
#
# */
#
#
# CREATE TABLE [APUNTE] (
# 	[ID_APUNTE] INTEGER NOT NULL IDENTITY(1,1),
# 	[Id_ASIENTO] INTEGER NOT NULL,
# 	[LINEA] INTEGER NOT NULL DEFAULT ((0)),
# 	[TIPO] NVARCHAR(2) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_CUENTA] INTEGER NOT NULL,
# 	[CONCEPTO] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DEBE] DECIMAL(18, 2) NOT NULL DEFAULT ((0)),
# 	[HABER] DECIMAL(18, 2) NOT NULL DEFAULT ((0)),
# 	[NDOCU] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FECDOCU] DATE NULL,
# 	[ENLACET] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_ENLACEN] INTEGER NULL,
# 	[PUNTEO_OR] INTEGER NULL,
# 	[PUNTEO_DS] INTEGER NULL,
# 	[BLOQUEO] BIT NOT NULL DEFAULT ((0)),
# 	[FECHAC] DATETIME NULL DEFAULT (getutcdate()),
# 	[FECHAM] DATETIME NULL,
# 	[Id_USUCRE] INTEGER NULL,
# 	[Id_USUMOD] INTEGER NULL,
# 	upsize_ts TIMESTAMP NULL,
# 	[STWF] INTEGER NOT NULL DEFAULT ((0)),
# 	CONSTRAINT [PK_APUNTES] PRIMARY KEY ([ID_APUNTE]),
# 	CONSTRAINT [FK_DIARIO_ASIENTO] FOREIGN KEY([Id_ASIENTO]) REFERENCES [ASIENTO] ([Id_ASIENTO]),
# 	CONSTRAINT [FK_DIARIO_PLANCUENTA] FOREIGN KEY([Id_CUENTA]) REFERENCES [PLANCUENTA] ([Id_CUENTA]),
# 	CONSTRAINT [FK_DIARIO_USUARIO] FOREIGN KEY([Id_USUCRE]) REFERENCES [USUARIO] ([Id_USUARIO]),
# 	CONSTRAINT [FK_DIARIO_USUARIO1] FOREIGN KEY([Id_USUMOD]) REFERENCES [USUARIO] ([Id_USUARIO])
# )
#
# /*
# 2 rows from APUNTE table:
# ID_APUNTE	Id_ASIENTO	LINEA	TIPO	Id_CUENTA	CONCEPTO	DEBE	HABER	NDOCU	FECDOCU	ENLACET	Id_ENLACEN	PUNTEO_OR	PUNTEO_DS	BLOQUEO	FECHAC	FECHAM	Id_USUCRE	Id_USUMOD	upsize_ts	STWF
# 197344	78937	1	None	3979	ASIENTO DE CIERRE	0.00	3005.06	None	None	None	None	None	None	False	2011-09-19 16:15:52.260000	None	1	None	b'\x00\x00\x00\x00\x00\x00\x07\xd1'	0
# 197345	78937	2	None	3990	ASIENTO DE CIERRE	0.00	5592.39	None	None	None	None	None	None	False	2011-09-19 16:15:52.263000	None	1	None	b'\x00\x00\x00\x00\x00\x00\x07\xd2'	0
# */
#
#
# CREATE TABLE [ARTICULOS_ESTRUC] (
# 	[Id_ESTRUC] INTEGER NOT NULL IDENTITY(1,1),
# 	[Id_ARTICULO] INTEGER NOT NULL,
# 	[Id_COMPON] INTEGER NOT NULL,
# 	[DESCRIP] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[CANTIDAD] DECIMAL(18, 4) NOT NULL,
# 	[BLOQUEO] BIT NOT NULL DEFAULT ((0)),
# 	[FECHAC] DATETIME NULL DEFAULT (getutcdate()),
# 	[FECHAM] DATETIME NULL,
# 	[Id_USUCRE] INTEGER NULL,
# 	[Id_USUMOD] INTEGER NULL,
# 	upsize_ts TIMESTAMP NULL,
# 	CONSTRAINT [PK_ARTICULOS_ESTRUC] PRIMARY KEY ([Id_ESTRUC]),
# 	CONSTRAINT [FK_ARTICULOS_ESTRUC_ARTICULO] FOREIGN KEY([Id_ARTICULO]) REFERENCES [ARTICULO] ([Id_ARTICULO]),
# 	CONSTRAINT [FK_ARTICULOS_ESTRUC_ARTICULO1] FOREIGN KEY([Id_COMPON]) REFERENCES [ARTICULO] ([Id_ARTICULO]),
# 	CONSTRAINT [FK_ARTICULOS_ESTRUC_USUARIO] FOREIGN KEY([Id_USUCRE]) REFERENCES [USUARIO] ([Id_USUARIO]),
# 	CONSTRAINT [FK_ARTICULOS_ESTRUC_USUARIO1] FOREIGN KEY([Id_USUMOD]) REFERENCES [USUARIO] ([Id_USUARIO])
# )
#
# /*
# 2 rows from ARTICULOS_ESTRUC table:
# Id_ESTRUC	Id_ARTICULO	Id_COMPON	DESCRIP	CANTIDAD	BLOQUEO	FECHAC	FECHAM	Id_USUCRE	Id_USUMOD	upsize_ts
# 2	310	305	Gestión integral de proyectos	1.0000	False	2012-02-07 11:58:30.837000	None	4	None	b'\x00\x00\x00\x00\x00\x01v='
# 3	311	306	Contabilidad	1.0000	False	2012-02-07 11:59:41.677000	None	4	None	b'\x00\x00\x00\x00\x00\x01v>'
# */
#
#
# CREATE TABLE [ARTICULO] (
# 	[Id_ARTICULO] INTEGER NOT NULL IDENTITY(1,1),
# 	[Id_EMPRESA] INTEGER NOT NULL,
# 	[TIPO] NVARCHAR(1) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL DEFAULT ('A'),
# 	[CODART] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[DENOMI] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[REF] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_GRUART] INTEGER NOT NULL,
# 	[Id_UNIDAD] INTEGER NULL,
# 	[Id_UNIDADC] INTEGER NULL,
# 	[PRECIOV] DECIMAL(18, 4) NOT NULL DEFAULT ((0)),
# 	[PRECIOC] DECIMAL(18, 4) NOT NULL DEFAULT ((0)),
# 	[Id_CUENTAC] INTEGER NULL,
# 	[Id_CUENTAV] INTEGER NULL,
# 	[Id_NATIVA] INTEGER NULL,
# 	[MOVI_STOCKS] BIT NOT NULL DEFAULT ((0)),
# 	[Id_RESPONSABLE] INTEGER NULL,
# 	[BLOQUEO] BIT NOT NULL DEFAULT ((0)),
# 	[FECHAC] DATETIME NULL DEFAULT (getutcdate()),
# 	[FECHAM] DATETIME NULL,
# 	[Id_USUCRE] INTEGER NULL,
# 	[Id_USUMOD] INTEGER NULL,
# 	upsize_ts TIMESTAMP NULL,
# 	[IMAGEN] BIT NOT NULL DEFAULT ((0)),
# 	[STWF] INTEGER NOT NULL DEFAULT ((0)),
# 	[CARAC] XML NULL,
# 	[Id_IVA_C] INTEGER NULL,
# 	[Id_IVA_V] INTEGER NULL,
# 	[SUPLIDO] BIT NOT NULL DEFAULT ((0)),
# 	[Id_IRPF] INTEGER NULL,
# 	[AGRUPAR_FACT] BIT NOT NULL DEFAULT ((1)),
# 	[Id_IVA_C_2] INTEGER NULL,
# 	[Id_IVA_C_3] INTEGER NULL,
# 	[Id_IVA_C_4] INTEGER NULL,
# 	[Id_RETENCION2] INTEGER NULL,
# 	[Id_RETENCION3] INTEGER NULL,
# 	[Id_RETENCION4] INTEGER NULL,
# 	[Id_IVA_V_2] INTEGER NULL,
# 	[Id_IVA_V_3] INTEGER NULL,
# 	[Id_IVA_V_4] INTEGER NULL,
# 	CONSTRAINT [PK_ARTICULOS] PRIMARY KEY ([Id_ARTICULO]),
# 	CONSTRAINT [FK_ARTICULO_EMPRESA] FOREIGN KEY([Id_EMPRESA]) REFERENCES [EMPRESA] ([Id_EMPRESA]),
# 	CONSTRAINT [FK_ARTICULO_GRUPOS_ARTICULO] FOREIGN KEY([Id_GRUART]) REFERENCES [GRUPOS_ARTICULO] ([Id_GRUART]),
# 	CONSTRAINT [FK_ARTICULO_IMPUESTO] FOREIGN KEY([Id_IRPF]) REFERENCES [IMPUESTO] ([Id_IMPUESTO]),
# 	CONSTRAINT [FK_ARTICULO_IMPUESTO_IVA_C] FOREIGN KEY([Id_IVA_C]) REFERENCES [IMPUESTO] ([Id_IMPUESTO]),
# 	CONSTRAINT [FK_ARTICULO_IMPUESTO_IVA_V] FOREIGN KEY([Id_IVA_V]) REFERENCES [IMPUESTO] ([Id_IMPUESTO]),
# 	CONSTRAINT [FK_ARTICULO_IMPUESTO_RET_2] FOREIGN KEY([Id_RETENCION2]) REFERENCES [IMPUESTO] ([Id_IMPUESTO]),
# 	CONSTRAINT [FK_ARTICULO_IMPUESTO_RET_3] FOREIGN KEY([Id_RETENCION3]) REFERENCES [IMPUESTO] ([Id_IMPUESTO]),
# 	CONSTRAINT [FK_ARTICULO_IMPUESTO_RET_4] FOREIGN KEY([Id_RETENCION4]) REFERENCES [IMPUESTO] ([Id_IMPUESTO]),
# 	CONSTRAINT [FK_ARTICULO_IVA_C_2] FOREIGN KEY([Id_IVA_C_2]) REFERENCES [IMPUESTO] ([Id_IMPUESTO]),
# 	CONSTRAINT [FK_ARTICULO_IVA_C_3] FOREIGN KEY([Id_IVA_C_3]) REFERENCES [IMPUESTO] ([Id_IMPUESTO]),
# 	CONSTRAINT [FK_ARTICULO_IVA_C_4] FOREIGN KEY([Id_IVA_C_4]) REFERENCES [IMPUESTO] ([Id_IMPUESTO]),
# 	CONSTRAINT [FK_ARTICULO_IVA_V_2] FOREIGN KEY([Id_IVA_V_2]) REFERENCES [IMPUESTO] ([Id_IMPUESTO]),
# 	CONSTRAINT [FK_ARTICULO_IVA_V_3] FOREIGN KEY([Id_IVA_V_3]) REFERENCES [IMPUESTO] ([Id_IMPUESTO]),
# 	CONSTRAINT [FK_ARTICULO_IVA_V_4] FOREIGN KEY([Id_IVA_V_4]) REFERENCES [IMPUESTO] ([Id_IMPUESTO]),
# 	CONSTRAINT [FK_ARTICULO_NATIVA] FOREIGN KEY([Id_NATIVA]) REFERENCES [NATIVA] ([Id_NATIVA]),
# 	CONSTRAINT [FK_ARTICULO_PLANCUENTA] FOREIGN KEY([Id_CUENTAC]) REFERENCES [PLANCUENTA] ([Id_CUENTA]),
# 	CONSTRAINT [FK_ARTICULO_PLANCUENTA1] FOREIGN KEY([Id_CUENTAV]) REFERENCES [PLANCUENTA] ([Id_CUENTA]),
# 	CONSTRAINT [FK_ARTICULO_T_RECURSO] FOREIGN KEY([Id_RESPONSABLE]) REFERENCES [T_RECURSO] ([Id_RECURSO]),
# 	CONSTRAINT [FK_ARTICULO_UNIDAD] FOREIGN KEY([Id_UNIDAD]) REFERENCES [UNIDAD] ([Id_UNIDAD]),
# 	CONSTRAINT [FK_ARTICULO_UNIDAD1] FOREIGN KEY([Id_UNIDADC]) REFERENCES [UNIDAD] ([Id_UNIDAD]),
# 	CONSTRAINT [FK_ARTICULO_USUARIO] FOREIGN KEY([Id_USUCRE]) REFERENCES [USUARIO] ([Id_USUARIO]),
# 	CONSTRAINT [FK_ARTICULO_USUARIO1] FOREIGN KEY([Id_USUMOD]) REFERENCES [USUARIO] ([Id_USUARIO])
# )
#
# /*
# 2 rows from ARTICULO table:
# Id_ARTICULO	Id_EMPRESA	TIPO	CODART	DENOMI	REF	Id_GRUART	Id_UNIDAD	Id_UNIDADC	PRECIOV	PRECIOC	Id_CUENTAC	Id_CUENTAV	Id_NATIVA	MOVI_STOCKS	Id_RESPONSABLE	BLOQUEO	FECHAC	FECHAM	Id_USUCRE	Id_USUMOD	upsize_ts	IMAGEN	STWF	CARAC	Id_IVA_C	Id_IVA_V	SUPLIDO	Id_IRPF	AGRUPAR_FACT	Id_IVA_C_2	Id_IVA_C_3	Id_IVA_C_4	Id_RETENCION2	Id_RETENCION3	Id_RETENCION4	Id_IVA_V_2	Id_IVA_V_3	Id_IVA_V_4
# 2	1	A	20	Contrato de Mantenimiento	None	65	2	2	0.0000	0.0000	595	4487	3	False	None	False	2011-09-12 09:43:49.497000	2012-11-21 14:45:38.167000	1	5	b'\x00\x00\x00\x00\x00\x01t\xc4'	False	0	None	12	2	False	None	True	None	None	None	None	None	None	None	None	None
# 3	1	A	H-ANALI	Horas Analista	None	32	2	2	95.0000	0.0000	595	4484	3	False	None	False	2011-09-12 09:43:49.517000	None	1	None	b'\x00\x00\x00\x00\x00\x01t\xc5'	False	0	None	12	2	False	None	True	None	None	None	None	None	None	None	None	None
# */
#
#
# CREATE TABLE [ASIENTO] (
# 	[Id_ASIENTO] INTEGER NOT NULL IDENTITY(1,1),
# 	[Id_EMPRESA] INTEGER NOT NULL,
# 	[FECHA] DATE NOT NULL,
# 	[NUMASIENTO] INTEGER NOT NULL,
# 	[NREFERENCIA] INTEGER NOT NULL,
# 	[Id_EJERCICIO] INTEGER NOT NULL,
# 	[TIPO] NVARCHAR(2) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[SREFERENCIA] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[NDOCU] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FECDOCU] DATE NULL,
# 	[ORIGEN] NVARCHAR(1) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_ENLACEN] INTEGER NULL,
# 	[PUNTEO_OR] INTEGER NULL,
# 	[PUNTEO_DS] INTEGER NULL,
# 	[BLOQUEO] BIT NOT NULL DEFAULT ((0)),
# 	[FECHAC] DATETIME NULL DEFAULT (getutcdate()),
# 	[FECHAM] DATETIME NULL,
# 	[Id_USUCRE] INTEGER NULL,
# 	[Id_USUMOD] INTEGER NULL,
# 	upsize_ts TIMESTAMP NULL,
# 	[R_NUMASIENTO] INTEGER NULL,
# 	[STWF] INTEGER NOT NULL DEFAULT ((0)),
# 	CONSTRAINT [PK_ASIENTO] PRIMARY KEY ([Id_ASIENTO]),
# 	CONSTRAINT [FK_ASIENTO_EJERCICIO] FOREIGN KEY([Id_EJERCICIO]) REFERENCES [EJERCICIO] ([Id_EJERCICIO]),
# 	CONSTRAINT [FK_ASIENTO_EMPRESA] FOREIGN KEY([Id_EMPRESA]) REFERENCES [EMPRESA] ([Id_EMPRESA]),
# 	CONSTRAINT [FK_ASIENTO_USUCRE] FOREIGN KEY([Id_USUCRE]) REFERENCES [USUARIO] ([Id_USUARIO]),
# 	CONSTRAINT [FK_ASIENTO_USUMOD] FOREIGN KEY([Id_USUMOD]) REFERENCES [USUARIO] ([Id_USUARIO])
# )
#
# /*
# 2 rows from ASIENTO table:
# Id_ASIENTO	Id_EMPRESA	FECHA	NUMASIENTO	NREFERENCIA	Id_EJERCICIO	TIPO	SREFERENCIA	NDOCU	FECDOCU	ORIGEN	Id_ENLACEN	PUNTEO_OR	PUNTEO_DS	BLOQUEO	FECHAC	FECHAM	Id_USUCRE	Id_USUMOD	upsize_ts	R_NUMASIENTO	STWF
# 78937	1	1995-12-31	1995000001	1995000001	1	M	None	None	None	None	None	None	None	False	2011-09-19 10:41:10.790000	None	1	None	b'\x00\x00\x00\x00\x00\x01vZ'	1995000001	0
# 78938	1	1995-12-31	1995900001	1995900001	1	R	None	None	None	None	None	None	None	False	2011-09-19 10:41:10.790000	None	1	None	b'\x00\x00\x00\x00\x00\x01v['	1995900001	0
# */
#
#
# CREATE TABLE [BALANCEL] (
# 	[Id_BAL_LINEA] INTEGER NOT NULL IDENTITY(1,1),
# 	[Id_BALANCE] INTEGER NOT NULL,
# 	[LINEA] INTEGER NULL,
# 	[ORDEN] INTEGER NULL,
# 	[NIVEL] INTEGER NULL,
# 	[DENOMI] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DENOMI_PIE] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[SIGNO] INTEGER NULL DEFAULT ((1)),
# 	[CONDI] INTEGER NULL DEFAULT ((0)),
# 	[AGRUP] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[TIPO] NVARCHAR(1) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_ESTILO_CAB] INTEGER NULL,
# 	[Id_ESTILO_PIE] INTEGER NULL,
# 	[BLOQUEO] BIT NOT NULL DEFAULT ((0)),
# 	[FECHAC] DATETIME NULL DEFAULT (getutcdate()),
# 	[FECHAM] DATETIME NULL,
# 	[Id_USUCRE] INTEGER NULL,
# 	[Id_USUMOD] INTEGER NULL,
# 	upsize_ts TIMESTAMP NULL,
# 	[STWF] INTEGER NOT NULL DEFAULT ((0)),
# 	CONSTRAINT [PK_BALANCEL] PRIMARY KEY ([Id_BAL_LINEA]),
# 	CONSTRAINT [FK_BALANCEL_BALANCE] FOREIGN KEY([Id_BALANCE]) REFERENCES [BALANCE] ([Id_BALANCE]),
# 	CONSTRAINT [FK_BALANCEL_ESTILOS_BAL] FOREIGN KEY([Id_ESTILO_CAB]) REFERENCES [ESTILOS_BAL] ([Id_ESTILO]),
# 	CONSTRAINT [FK_BALANCEL_ESTILOS_BAL1] FOREIGN KEY([Id_ESTILO_PIE]) REFERENCES [ESTILOS_BAL] ([Id_ESTILO]),
# 	CONSTRAINT [FK_BALANCEL_USUARIO] FOREIGN KEY([Id_USUCRE]) REFERENCES [USUARIO] ([Id_USUARIO]),
# 	CONSTRAINT [FK_BALANCEL_USUARIO1] FOREIGN KEY([Id_USUMOD]) REFERENCES [USUARIO] ([Id_USUARIO])
# )
#
# /*
# 2 rows from BALANCEL table:
# Id_BAL_LINEA	Id_BALANCE	LINEA	ORDEN	NIVEL	DENOMI	DENOMI_PIE	SIGNO	CONDI	AGRUP	TIPO	Id_ESTILO_CAB	Id_ESTILO_PIE	BLOQUEO	FECHAC	FECHAM	Id_USUCRE	Id_USUMOD	upsize_ts	STWF
# 1	1	1001	10000	0	ACTIVO	TOTAL ACTIVO	1	0	000.000.000.000.000.000	N	None	None	False	2011-09-07 17:35:57.743000	None	1	None	b'\x00\x00\x00\x00\x00\x01\xe4\xee'	0
# 2	1	1002	11000	1	A) ACTIVO NO CORRIENTE	None	1	0	000.010.000.000.000.000	N	None	None	False	2011-09-07 17:35:57.743000	None	1	None	b'\x00\x00\x00\x00\x00\x01\xe4\xef'	0
# */
#
#
# CREATE TABLE [BALANCEL_MASA] (
# 	[Id_BAL_LINEA] INTEGER NOT NULL,
# 	[Id_MASA] INTEGER NOT NULL,
# 	[SIGNO] INTEGER NULL DEFAULT ((1)),
# 	[BLOQUEO] BIT NOT NULL DEFAULT ((0)),
# 	[FECHAC] DATETIME NULL DEFAULT (getutcdate()),
# 	[FECHAM] DATETIME NULL,
# 	[Id_USUCRE] INTEGER NULL,
# 	[Id_USUMOD] INTEGER NULL,
# 	[STWF] INTEGER NOT NULL DEFAULT ((0)),
# 	CONSTRAINT [PK_BALANCEL_MASA] PRIMARY KEY ([Id_BAL_LINEA], [Id_MASA]),
# 	CONSTRAINT [FK_BALANCEL_MASA_BALANCEL] FOREIGN KEY([Id_BAL_LINEA]) REFERENCES [BALANCEL] ([Id_BAL_LINEA]),
# 	CONSTRAINT [FK_BALANCEL_MASA_MASA] FOREIGN KEY([Id_MASA]) REFERENCES [MASA] ([Id_MASA]),
# 	CONSTRAINT [FK_BALANCEL_MASA_USUARIO] FOREIGN KEY([Id_USUCRE]) REFERENCES [USUARIO] ([Id_USUARIO]),
# 	CONSTRAINT [FK_BALANCEL_MASA_USUARIO1] FOREIGN KEY([Id_USUMOD]) REFERENCES [USUARIO] ([Id_USUARIO])
# )
#
# /*
# 2 rows from BALANCEL_MASA table:
# Id_BAL_LINEA	Id_MASA	SIGNO	BLOQUEO	FECHAC	FECHAM	Id_USUCRE	Id_USUMOD	STWF
# 9	24	1	False	2011-09-07 17:35:57.743000	None	1	None	0
# 10	25	1	False	2011-09-07 17:35:57.743000	None	1	None	0
# */
#
#
# CREATE TABLE [BALANCE] (
# 	[Id_BALANCE] INTEGER NOT NULL IDENTITY(1,1),
# 	[Id_EMPRESA] INTEGER NOT NULL,
# 	[CODBAL] NVARCHAR(20) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[DENOMI] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PRINCIPAL] BIT NULL DEFAULT ((0)),
# 	[BLOQUEO] BIT NOT NULL DEFAULT ((0)),
# 	[FECHAC] DATETIME NULL DEFAULT (getutcdate()),
# 	[FECHAM] DATETIME NULL,
# 	[Id_USUCRE] INTEGER NULL,
# 	[Id_USUMOD] INTEGER NULL,
# 	upsize_ts TIMESTAMP NULL,
# 	[STWF] INTEGER NOT NULL DEFAULT ((0)),
# 	CONSTRAINT [PK_BALANCES] PRIMARY KEY ([Id_BALANCE]),
# 	CONSTRAINT [FK_BALANCE_EMPRESA] FOREIGN KEY([Id_EMPRESA]) REFERENCES [EMPRESA] ([Id_EMPRESA]),
# 	CONSTRAINT [FK_BALANCE_USUARIO] FOREIGN KEY([Id_USUCRE]) REFERENCES [USUARIO] ([Id_USUARIO]),
# 	CONSTRAINT [FK_BALANCE_USUARIO1] FOREIGN KEY([Id_USUMOD]) REFERENCES [USUARIO] ([Id_USUARIO])
# )
#
# /*
# 2 rows from BALANCE table:
# Id_BALANCE	Id_EMPRESA	CODBAL	DENOMI	PRINCIPAL	BLOQUEO	FECHAC	FECHAM	Id_USUCRE	Id_USUMOD	upsize_ts	STWF
# 1	1	BALANCE NORMAL	BALANCE DE SITUACION	True	False	2011-09-07 17:35:57.743000	None	1	None	b'\x00\x00\x00\x00\x00\x01\xe4\xe8'	0
# 2	1	CUENTA  PPGG NORMAL	CUENTA DE PERDIDAS Y GANANCIAS	True	False	2011-09-07 17:35:57.743000	None	1	None	b'\x00\x00\x00\x00\x00\x01\xe4\xe9'	0
# */
#
#
# CREATE TABLE [BANCO] (
# 	[Id_BANCO] INTEGER NOT NULL IDENTITY(1,1),
# 	[Id_EMPRESA] INTEGER NOT NULL,
# 	[CODBANCO] NVARCHAR(5) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[Id_PAIS] INTEGER NULL,
# 	[Id_DIVISA] INTEGER NOT NULL,
# 	[CIF] NVARCHAR(20) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[DENOMI] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[CONTACTO] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DIRECC] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CODPOS] NVARCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[LOCALIDAD] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_PROVINCIA] INTEGER NULL,
# 	[TEL] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[TEL2] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FAX] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[WWW] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[EMAIL1] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[EMAIL2] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[EMAIL3] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[SREFER] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[NREFER] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_GRUPDOC] INTEGER NULL,
# 	[Id_CUENTA] INTEGER NOT NULL,
# 	[Id_PROVEE] INTEGER NULL,
# 	[SWIFT] NVARCHAR(11) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[IBAN] NVARCHAR(40) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[BLOQUEO] BIT NOT NULL DEFAULT ((0)),
# 	[FECHAC] DATETIME NULL DEFAULT (getutcdate()),
# 	[FECHAM] DATETIME NULL,
# 	[Id_USUCRE] INTEGER NULL,
# 	[Id_USUMOD] INTEGER NULL,
# 	upsize_ts TIMESTAMP NULL,
# 	[STWF] INTEGER NOT NULL DEFAULT ((0)),
# 	CONSTRAINT [PK_BANCOS] PRIMARY KEY ([Id_BANCO]),
# 	CONSTRAINT [FK_BANCO_DIVISA] FOREIGN KEY([Id_DIVISA]) REFERENCES [DIVISA] ([Id_DIVISA]),
# 	CONSTRAINT [FK_BANCO_EMPRESA] FOREIGN KEY([Id_EMPRESA]) REFERENCES [EMPRESA] ([Id_EMPRESA]),
# 	CONSTRAINT [FK_BANCO_GRUPOSDOCUMENTOS] FOREIGN KEY([Id_GRUPDOC]) REFERENCES [GRUPOS_DOCUMENTO] ([Id_GRUPDOC]),
# 	CONSTRAINT [FK_BANCO_NACION] FOREIGN KEY([Id_PAIS]) REFERENCES [NACION] ([Id_PAIS]),
# 	CONSTRAINT [FK_BANCO_PLANCUENTA] FOREIGN KEY([Id_CUENTA]) REFERENCES [PLANCUENTA] ([Id_CUENTA]),
# 	CONSTRAINT [FK_BANCO_PROVEEDOR] FOREIGN KEY([Id_PROVEE]) REFERENCES [PROVEEDOR] ([Id_PROVEE]),
# 	CONSTRAINT [FK_BANCO_PROVINCIA] FOREIGN KEY([Id_PROVINCIA]) REFERENCES [PROVINCIA] ([Id_PROVINCIA]),
# 	CONSTRAINT [FK_BANCO_USUARIOC] FOREIGN KEY([Id_USUCRE]) REFERENCES [USUARIO] ([Id_USUARIO]),
# 	CONSTRAINT [FK_BANCO_USUARIOM] FOREIGN KEY([Id_USUMOD]) REFERENCES [USUARIO] ([Id_USUARIO])
# )
#
# /*
# 2 rows from BANCO table:
# Id_BANCO	Id_EMPRESA	CODBANCO	Id_PAIS	Id_DIVISA	CIF	DENOMI	CONTACTO	DIRECC	CODPOS	LOCALIDAD	Id_PROVINCIA	TEL	TEL2	FAX	WWW	EMAIL1	EMAIL2	EMAIL3	SREFER	NREFER	Id_GRUPDOC	Id_CUENTA	Id_PROVEE	SWIFT	IBAN	BLOQUEO	FECHAC	FECHAM	Id_USUCRE	Id_USUMOD	upsize_ts	STWF
# 31	1	00001	65	46	1	BANKINTER	Feli Lanau	ELCANO, 10	20004	SAN SEBASTIAN	20	943 447236	None	943 447209	None	mflanau@bankinter.es	None	None	None	None	1	2117	None	None	01280340130502029441	False	2011-09-15 14:23:48.077000	None	1	None	b'\x00\x00\x00\x00\x00\x01\xe6N'	0
# 32	1	00002	65	46	1	KUTXA	Ana Arregui	O.EMP.:GARIBAY, 15	20004	SAN SEBASTIAN	20	943 411000	None	943 430186	None	aarregui@kutxa.es	None	None	None	None	1	2118	None	BASKES2BXXX	20955206051062217103	False	2011-09-15 14:23:48.080000	2014-02-13 15:39:40.507000	1	5	b'\x00\x00\x00\x00\x00\x01\xe6O'	0
# */
#
#
# CREATE TABLE [CARACTERISTICA] (
# 	[Id_CARAC] INTEGER NOT NULL IDENTITY(1,1),
# 	[Id_EMPRESA] INTEGER NOT NULL,
# 	[CLASE] NVARCHAR(1) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL DEFAULT ('A'),
# 	[CARAC] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[DENOMI] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[TIPO] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[TIPOCONTROL] NVARCHAR(1) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[LIMITAR] BIT NOT NULL,
# 	[DATOS] XML NULL,
# 	[BLOQUEO] BIT NOT NULL DEFAULT ((0)),
# 	[FECHAC] DATETIME NULL DEFAULT (getutcdate()),
# 	[FECHAM] DATETIME NULL,
# 	[Id_USUCRE] INTEGER NULL,
# 	[Id_USUMOD] INTEGER NULL,
# 	upsize_ts TIMESTAMP NULL,
# 	[STWF] INTEGER NOT NULL DEFAULT ((0)),
# 	CONSTRAINT [PK_CARACTERISTICA] PRIMARY KEY ([Id_CARAC]),
# 	CONSTRAINT [FK_CARACTERISTICA_EMPRESA] FOREIGN KEY([Id_EMPRESA]) REFERENCES [EMPRESA] ([Id_EMPRESA]),
# 	CONSTRAINT [FK_CARACTERISTICA_USUARIO] FOREIGN KEY([Id_USUCRE]) REFERENCES [USUARIO] ([Id_USUARIO]),
# 	CONSTRAINT [FK_CARACTERISTICA_USUARIO1] FOREIGN KEY([Id_USUMOD]) REFERENCES [USUARIO] ([Id_USUARIO])
# )
#
# /*
# 2 rows from CARACTERISTICA table:
# Id_CARAC	Id_EMPRESA	CLASE	CARAC	DENOMI	TIPO	TIPOCONTROL	LIMITAR	DATOS	BLOQUEO	FECHAC	FECHAM	Id_USUCRE	Id_USUMOD	upsize_ts	STWF
# 2	1	A	SAAS_P	Artículo SaaS de Venta 	T	L	True	<r><c>S</c><c>N</c></r>	False	2012-02-07 10:48:01.073000	2012-02-07 11:35:12.163000	4	4	b'\x00\x00\x00\x00\x00\x01\xe6['	0
# 3	1	A	SAAS_1	Producto Venta Unitario	T	L	True	<r><c>S</c><c>N</c></r>	False	2012-02-07 10:58:22.133000	2012-02-07 14:40:13.773000	4	4	b'\x00\x00\x00\x00\x00\x01\xe6\\'	0
# */
#
#
# CREATE TABLE [CLIENTES_USU_LICENCIA] (
# 	[Id] INTEGER NOT NULL IDENTITY(1,1),
# 	[Id_EMPRESA] INTEGER NOT NULL,
# 	[CODCLI] NVARCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[CODUSU] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_ARTICULO] INTEGER NOT NULL,
# 	[ACCESO] BIT NOT NULL DEFAULT ((0)),
# 	[BLOQUEO] BIT NOT NULL DEFAULT ((0)),
# 	[FECHAC] DATETIME NULL DEFAULT (getutcdate()),
# 	[FECHAM] DATETIME NULL,
# 	upsize_ts TIMESTAMP NULL,
# 	[STWF] INTEGER NOT NULL DEFAULT ((0)),
# 	[FLAG] BIT NOT NULL DEFAULT ((0)),
# 	[Id_LINEA_PED] INTEGER NOT NULL,
# 	[ESTADO] NVARCHAR(1) COLLATE SQL_Latin1_General_CP1_CI_AS NULL DEFAULT (N'V'),
# 	[FECHA_VALIDA] DATE NULL,
# 	[FECHA_ULT_ASIGNA] DATETIME NULL,
# 	CONSTRAINT [PK_CLIENTES_USU_LICENCIA] PRIMARY KEY ([Id]),
# 	CONSTRAINT [FK_CLIENTES_USU_LICENCIA_ARTICULO] FOREIGN KEY([Id_ARTICULO]) REFERENCES [ARTICULO] ([Id_ARTICULO]),
# 	CONSTRAINT [FK_CLIENTES_USU_LICENCIA_CLIENTES_USU_LICENCIA] FOREIGN KEY([Id_LINEA_PED]) REFERENCES [T_ORDTERL] ([Id_LINEA_PED]),
# 	CONSTRAINT [FK_CLIENTES_USU_LICENCIA_EMPRESA] FOREIGN KEY([Id_EMPRESA]) REFERENCES [EMPRESA] ([Id_EMPRESA])
# )
#
# /*
# 2 rows from CLIENTES_USU_LICENCIA table:
# Id	Id_EMPRESA	CODCLI	CODUSU	Id_ARTICULO	ACCESO	BLOQUEO	FECHAC	FECHAM	upsize_ts	STWF	FLAG	Id_LINEA_PED	ESTADO	FECHA_VALIDA	FECHA_ULT_ASIGNA
# 10	1	SA00100001	None	308	True	False	2012-03-06 23:22:52.513000	None	b'\x00\x00\x00\x00\x00\x01\xeb<'	0	True	6299	None	2099-01-24	None
# 11	1	SA00100001	None	308	True	False	2012-03-06 23:22:52.513000	None	b'\x00\x00\x00\x00\x00\x01\xeb='	0	True	6300	None	2099-01-24	None
# */
#
#
# CREATE TABLE [CLIENTE] (
# 	[Id_CLIENTE] INTEGER NOT NULL IDENTITY(1,1),
# 	[Id_EMPRESA] INTEGER NOT NULL,
# 	[CODCLI] NVARCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[Id_GRUCLI] INTEGER NOT NULL,
# 	[Id_DIVISA] INTEGER NOT NULL,
# 	[CIF] NVARCHAR(20) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[DENOMI] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[CONTACTO] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DIRECC] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CODPOS] NVARCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[LOCALIDAD] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_PAIS] INTEGER NULL,
# 	[Id_PROVINCIA] INTEGER NULL,
# 	[GMT] INTEGER NULL DEFAULT ((0)),
# 	[TEL] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[TEL2] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FAX] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[WWW] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[EMAIL1] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[EMAIL2] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[EMAIL3] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[SREFER] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[NREFER] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_GRUPDOC] INTEGER NULL,
# 	[Id_CUENTA] INTEGER NULL,
# 	[Id_NATIVA] INTEGER NULL,
# 	[Id_FPAGO] INTEGER NULL,
# 	[Id_CONDIPAGO] INTEGER NULL,
# 	[Id_BANCO] INTEGER NULL,
# 	[SWIFT] NVARCHAR(11) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[IBAN] NVARCHAR(40) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_DTO] INTEGER NULL,
# 	[Id_REC] INTEGER NULL,
# 	[LIMCRED] DECIMAL(18, 2) NULL DEFAULT ((0)),
# 	[FACELEC] BIT NOT NULL DEFAULT ((0)),
# 	[BLOQUEO] BIT NOT NULL DEFAULT ((0)),
# 	[FECHAC] DATETIME NULL DEFAULT (getutcdate()),
# 	[FECHAM] DATETIME NULL,
# 	[Id_USUCRE] INTEGER NULL,
# 	[Id_USUMOD] INTEGER NULL,
# 	upsize_ts TIMESTAMP NULL,
# 	[STWF] INTEGER NOT NULL DEFAULT ((0)),
# 	[Id_REPRES] INTEGER NULL,
# 	[NIFE] NVARCHAR(20) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[NOAPLICA_IRPF] BIT NOT NULL DEFAULT ((0)),
# 	[REGIMEN_IVA] NVARCHAR(1) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL DEFAULT ((1)),
# 	[DIR_IP] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[NOAPLICA_RET_2] BIT NOT NULL DEFAULT ((0)),
# 	[NOAPLICA_RET_3] BIT NOT NULL DEFAULT ((0)),
# 	[NOAPLICA_RET_4] BIT NOT NULL DEFAULT ((0)),
# 	[MANDATO] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[MANDATO_FECHA] DATE NULL,
# 	[MANDATO_PERIODICIDAD] NVARCHAR(5) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[MANDATO_MARCA] BIT NULL,
# 	[MANDATO_FECHA_OP] DATETIME2 NULL,
# 	CONSTRAINT [PK_CLIENTES] PRIMARY KEY ([Id_CLIENTE]),
# 	CONSTRAINT [FK_CLIENTE_BANCO] FOREIGN KEY([Id_BANCO]) REFERENCES [BANCO] ([Id_BANCO]),
# 	CONSTRAINT [FK_CLIENTE_CONDICIONES_PAGO] FOREIGN KEY([Id_CONDIPAGO]) REFERENCES [CONDICIONES_PAGO] ([Id_CONDIPAGO]),
# 	CONSTRAINT [FK_CLIENTE_DESCUENTO] FOREIGN KEY([Id_DTO]) REFERENCES [DESCUENTO] ([Id_DTO]),
# 	CONSTRAINT [FK_CLIENTE_DESCUENTO1] FOREIGN KEY([Id_REC]) REFERENCES [DESCUENTO] ([Id_DTO]),
# 	CONSTRAINT [FK_CLIENTE_DIVISA] FOREIGN KEY([Id_DIVISA]) REFERENCES [DIVISA] ([Id_DIVISA]),
# 	CONSTRAINT [FK_CLIENTE_EMPRESA] FOREIGN KEY([Id_EMPRESA]) REFERENCES [EMPRESA] ([Id_EMPRESA]),
# 	CONSTRAINT [FK_CLIENTE_FPAGO] FOREIGN KEY([Id_FPAGO]) REFERENCES [FPAGO] ([Id_FPAGO]),
# 	CONSTRAINT [FK_CLIENTE_GRUPOS_CLIENTE] FOREIGN KEY([Id_GRUCLI]) REFERENCES [GRUPOS_CLIENTE] ([Id_GRUCLI]),
# 	CONSTRAINT [FK_CLIENTE_GRUPOS_DOCUMENTO] FOREIGN KEY([Id_GRUPDOC]) REFERENCES [GRUPOS_DOCUMENTO] ([Id_GRUPDOC]),
# 	CONSTRAINT [FK_CLIENTE_NACION] FOREIGN KEY([Id_PAIS]) REFERENCES [NACION] ([Id_PAIS]),
# 	CONSTRAINT [FK_CLIENTE_NATIVA] FOREIGN KEY([Id_NATIVA]) REFERENCES [NATIVA] ([Id_NATIVA]),
# 	CONSTRAINT [FK_CLIENTE_PLANCUENTA] FOREIGN KEY([Id_CUENTA]) REFERENCES [PLANCUENTA] ([Id_CUENTA]),
# 	CONSTRAINT [FK_CLIENTE_PROVEEDOR] FOREIGN KEY([Id_REPRES]) REFERENCES [PROVEEDOR] ([Id_PROVEE]),
# 	CONSTRAINT [FK_CLIENTE_PROVINCIA] FOREIGN KEY([Id_PROVINCIA]) REFERENCES [PROVINCIA] ([Id_PROVINCIA]),
# 	CONSTRAINT [FK_CLIENTE_USUARIO] FOREIGN KEY([Id_USUCRE]) REFERENCES [USUARIO] ([Id_USUARIO]),
# 	CONSTRAINT [FK_CLIENTE_USUARIO1] FOREIGN KEY([Id_USUMOD]) REFERENCES [USUARIO] ([Id_USUARIO])
# )
#
# /*
# 2 rows from CLIENTE table:
# Id_CLIENTE	Id_EMPRESA	CODCLI	Id_GRUCLI	Id_DIVISA	CIF	DENOMI	CONTACTO	DIRECC	CODPOS	LOCALIDAD	Id_PAIS	Id_PROVINCIA	GMT	TEL	TEL2	FAX	WWW	EMAIL1	EMAIL2	EMAIL3	SREFER	NREFER	Id_GRUPDOC	Id_CUENTA	Id_NATIVA	Id_FPAGO	Id_CONDIPAGO	Id_BANCO	SWIFT	IBAN	Id_DTO	Id_REC	LIMCRED	FACELEC	BLOQUEO	FECHAC	FECHAM	Id_USUCRE	Id_USUMOD	upsize_ts	STWF	Id_REPRES	NIFE	NOAPLICA_IRPF	REGIMEN_IVA	DIR_IP	NOAPLICA_RET_2	NOAPLICA_RET_3	NOAPLICA_RET_4	MANDATO	MANDATO_FECHA	MANDATO_PERIODICIDAD	MANDATO_MARCA	MANDATO_FECHA_OP
# 1	1	000001	1	46	A20005427	GRUPO MZ	D.Jesús Luengo	Polígono Lebario, Nº2 - Apartado 49	48220	Abadiano	65	20	1	943,82,16,00	None	None	None	jluengo@grupomz.com	None	None	None	None	1	992	4	11	4	None	None	None	None	None	0.00	False	False	2011-09-13 08:29:48.937000	None	1	None	b'\x00\x00\x00\x00\x00\x01\xe6e'	0	None	None	False	1	None	False	False	False	None	None	None	None	None
# 2	1	000002	1	46	A20000246	MANUFACTURAS PHILLIPS SCREW,SA	D. Luis Aguirrezabal	Polígono Industrial EITUA, nº63	48240	BERRIZ	65	48	1	None	None	None	None	luis@mafisa.com	None	None	None	None	1	993	4	4	4	None	None	None	None	None	0.00	False	False	2011-09-13 08:29:48.937000	None	1	None	b'\x00\x00\x00\x00\x00\x01\xe6f'	0	None	None	False	1	None	False	False	False	None	None	None	None	None
# */
#
#
# CREATE TABLE [CONDICIONES_PAGO] (
# 	[Id_CONDIPAGO] INTEGER NOT NULL IDENTITY(1,1),
# 	[Id_EMPRESA] INTEGER NULL,
# 	[CONDIPAGO] NVARCHAR(5) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[DENOMI] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[NPAGOS] SMALLINT NOT NULL DEFAULT ((1)),
# 	[DIAS1] SMALLINT NOT NULL DEFAULT ((0)),
# 	[CADENCIA] SMALLINT NOT NULL DEFAULT ((0)),
# 	[DFIJO1] SMALLINT NOT NULL DEFAULT ((0)),
# 	[DFIJO2] SMALLINT NOT NULL DEFAULT ((0)),
# 	[DFIJO3] SMALLINT NOT NULL DEFAULT ((0)),
# 	[VACAD] SMALLDATETIME NULL,
# 	[VACAH] SMALLDATETIME NULL,
# 	[DIAPAGOV1] SMALLDATETIME NULL,
# 	[DIAPAGOV2] SMALLDATETIME NULL,
# 	[BLOQUEO] BIT NOT NULL DEFAULT ((0)),
# 	[FECHAC] DATETIME NULL DEFAULT (getutcdate()),
# 	[FECHAM] DATETIME NULL,
# 	[Id_USUCRE] INTEGER NULL,
# 	[Id_USUMOD] INTEGER NULL,
# 	upsize_ts TIMESTAMP NULL,
# 	[STWF] INTEGER NOT NULL DEFAULT ((0)),
# 	CONSTRAINT [PK_CONDICIONES_PAGO_1] PRIMARY KEY ([Id_CONDIPAGO])
# )
#
# /*
# 2 rows from CONDICIONES_PAGO table:
# Id_CONDIPAGO	Id_EMPRESA	CONDIPAGO	DENOMI	NPAGOS	DIAS1	CADENCIA	DFIJO1	DFIJO2	DFIJO3	VACAD	VACAH	DIAPAGOV1	DIAPAGOV2	BLOQUEO	FECHAC	FECHAM	Id_USUCRE	Id_USUMOD	upsize_ts	STWF
# 1	1	30	1 Pago a 30 días	1	30	0	0	0	0	None	None	None	None	False	2011-09-07 17:35:57.743000	None	1	None	b'\x00\x00\x00\x00\x00\x01\xef\x8e'	0
# 2	1	60	1 Pago a 60 días	1	60	0	0	0	0	None	None	None	None	False	2011-09-07 17:35:57.743000	None	1	None	b'\x00\x00\x00\x00\x00\x01\xef\x8f'	0
# */
#
#
# CREATE TABLE [CONFIG_LISNAV] (
# 	[Id_CONFIGLIS] INTEGER NOT NULL IDENTITY(1,1),
# 	[Id_EMPRESA] INTEGER NULL,
# 	[GRUPO] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[TITULO] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CONFIGLIS] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DENOMI] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[REPORT] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[NIVEL] INTEGER NOT NULL DEFAULT ((0)),
# 	[AGRUP] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[AGRUP1] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[AGRUP2] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[AGRUP3] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DET1] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DET2] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DET3] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DET4] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DET5] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DET6] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DET7] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DET8] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DET9] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[ORDENACION] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[MAPEAR] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FRM1] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FRM2] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FRM3] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FRM4] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FRM5] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FRM6] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FRM7] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FRM8] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FRM9] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[VISIBLE] BIT NULL DEFAULT ((1)),
# 	[COLR] INTEGER NOT NULL DEFAULT ((0)),
# 	[COLG] INTEGER NOT NULL DEFAULT ((0)),
# 	[COLB] INTEGER NOT NULL DEFAULT ((0)),
# 	[LANDSC] BIT NOT NULL DEFAULT ((0)),
# 	[MANTJUNTOS] INTEGER NULL DEFAULT ((0)),
# 	[BOOKMARK] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[SALTAR] INTEGER NULL DEFAULT ((0)),
# 	[IMP_SIEMPRE] BIT NULL DEFAULT ((0)),
# 	[ALTO] DECIMAL(18, 2) NULL DEFAULT ((0)),
# 	[FORMATOS] XML NULL,
# 	[PARAMETROS] NVARCHAR(max) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[BLOQUEO] BIT NOT NULL DEFAULT ((0)),
# 	[FECHAC] DATETIME NULL,
# 	[FECHAM] DATETIME NULL,
# 	[Id_USUCRE] INTEGER NULL,
# 	[Id_USUMOD] INTEGER NULL,
# 	upsize_ts TIMESTAMP NULL,
# 	[STWF] INTEGER NOT NULL DEFAULT ((0)),
# 	CONSTRAINT [PK_CONFIG_LISNAV] PRIMARY KEY ([Id_CONFIGLIS]),
# 	CONSTRAINT [FK_CONFIG_LISNAV_EMPRESA] FOREIGN KEY([Id_EMPRESA]) REFERENCES [EMPRESA] ([Id_EMPRESA]),
# 	CONSTRAINT [FK_CONFIG_LISNAV_USUARIOC] FOREIGN KEY([Id_USUCRE]) REFERENCES [USUARIO] ([Id_USUARIO]),
# 	CONSTRAINT [FK_CONFIG_LISNAV_USUARIOM] FOREIGN KEY([Id_USUMOD]) REFERENCES [USUARIO] ([Id_USUARIO])
# )
#
# /*
# 2 rows from CONFIG_LISNAV table:
# Id_CONFIGLIS	Id_EMPRESA	GRUPO	TITULO	CONFIGLIS	DENOMI	REPORT	NIVEL	AGRUP	AGRUP1	AGRUP2	AGRUP3	DET1	DET2	DET3	DET4	DET5	DET6	DET7	DET8	DET9	ORDENACION	MAPEAR	FRM1	FRM2	FRM3	FRM4	FRM5	FRM6	FRM7	FRM8	FRM9	VISIBLE	COLR	COLG	COLB	LANDSC	MANTJUNTOS	BOOKMARK	SALTAR	IMP_SIEMPRE	ALTO	FORMATOS	PARAMETROS	BLOQUEO	FECHAC	FECHAM	Id_USUCRE	Id_USUMOD	upsize_ts	STWF
# 1	1	ANALISIS	ANALISIS DE PROYECTOS	1	PROYECTOS + RECURSOS	R_Gip_H6x9cs	0	[COD_TIPO]	=	H	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	None	False	255	255	255	True	0	None	0	False	0.00	None	None	False	2011-09-07 17:35:57.743000	None	1	None	b'\x00\x00\x00\x00\x00\x01\xef\x9e'	0
# 2	1	ANALISIS	ANALISIS DE PROYECTOS	1	PROYECTOS + RECURSOS	R_Gip_H6x9cs	2	[Id_PROYECTO]	None	None	None	[COD_PROYECTO] + " " + [TEX_PROYECTO]	None	None	None	None	None	None	None	None	[COD_PROYECTO]	[COD_PROYECTO] + '-' + [TEX_PROYECTO]	None	None	None	None	None	None	None	None	None	True	255	255	255	True	0	None	0	False	0.00	None	None	False	2011-09-07 17:35:57.743000	None	1	None	b'\x00\x00\x00\x00\x00\x01\xef\x9f'	0
# */
#
#
# CREATE TABLE [CONTADOR] (
# 	[Id_CONTADOR] INTEGER NOT NULL IDENTITY(1,1),
# 	[Id_EMPRESA] INTEGER NOT NULL,
# 	[CODCONTAD] NVARCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[PERIODO] NVARCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[FINICIO] DATE NULL,
# 	[FFINAL] DATE NULL,
# 	[DENOMI] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DESDE] INTEGER NOT NULL DEFAULT ((0)),
# 	[HASTA] INTEGER NOT NULL DEFAULT ((0)),
# 	[INTERVALO] INTEGER NOT NULL DEFAULT ((1)),
# 	[NUMACT] INTEGER NOT NULL DEFAULT ((0)),
# 	[NCARAC] INTEGER NOT NULL DEFAULT ((0)),
# 	[BLOQUEO] BIT NOT NULL DEFAULT ((0)),
# 	[FECHAC] DATETIME NULL DEFAULT (getutcdate()),
# 	[FECHAM] DATETIME NULL,
# 	[Id_USUCRE] INTEGER NULL,
# 	[Id_USUMOD] INTEGER NULL,
# 	upsize_ts TIMESTAMP NULL,
# 	[STWF] INTEGER NOT NULL DEFAULT ((0)),
# 	CONSTRAINT [PK_CONTADORES] PRIMARY KEY ([Id_CONTADOR]),
# 	CONSTRAINT [FK_CONTADOR_EMPRESA] FOREIGN KEY([Id_EMPRESA]) REFERENCES [EMPRESA] ([Id_EMPRESA]),
# 	CONSTRAINT [FK_CONTADOR_USUARIO] FOREIGN KEY([Id_USUCRE]) REFERENCES [USUARIO] ([Id_USUARIO]),
# 	CONSTRAINT [FK_CONTADOR_USUARIO1] FOREIGN KEY([Id_USUMOD]) REFERENCES [USUARIO] ([Id_USUARIO])
# )
#
# /*
# 2 rows from CONTADOR table:
# Id_CONTADOR	Id_EMPRESA	CODCONTAD	PERIODO	FINICIO	FFINAL	DENOMI	DESDE	HASTA	INTERVALO	NUMACT	NCARAC	BLOQUEO	FECHAC	FECHAM	Id_USUCRE	Id_USUMOD	upsize_ts	STWF
# 1	1	BA	1	None	None	Contador de Bancos	1	999999	1	11	0	False	2011-09-07 17:35:57.743000	2013-01-31 15:48:26.640000	1	4	b'\x00\x00\x00\x00\x00\x01\xf0;'	0
# 2	1	CL	1	None	None	Contador de Clientes	1	999999	1	339	0	False	2011-09-07 17:35:57.743000	2013-01-28 19:41:31.747000	1	12	b'\x00\x00\x00\x00\x00\x01\xf0<'	0
# */
#
#
# CREATE TABLE [CONTRATO_PAGO] (
# 	[Id_CONTRATO_PAGO] INTEGER NOT NULL IDENTITY(1,1),
# 	[Id_PEDIDO] INTEGER NOT NULL,
# 	[IMPORTE] DECIMAL(18, 4) NOT NULL,
# 	[DIRECCION_IP] NVARCHAR(45) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[USERAGENT] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PAGO_CODIGO_AUTH] NVARCHAR(30) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PAGO_SEGURO] BIT NULL,
# 	[FECHA_RESPUESTA] DATETIME NULL,
# 	[RESPUESTA] NVARCHAR(20) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PAGO_ESTADO] NCHAR(1) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[Id_NRO] INTEGER NOT NULL,
# 	[ORIGEN] NVARCHAR(2) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FECHAC] DATETIME NULL,
# 	[FECHAM] DATETIME NULL,
# 	[FECHAP] DATETIME NULL,
# 	CONSTRAINT [PK_CONTRATO_PAGO] PRIMARY KEY ([Id_CONTRATO_PAGO]),
# 	CONSTRAINT [FK_CONTRATO_PAGO_T_FACTURA_VTO] FOREIGN KEY([Id_NRO]) REFERENCES [T_FACTURA_VTO] ([Id_NRO]),
# 	CONSTRAINT [FK_CONTRATO_PAGO_T_ORDTER] FOREIGN KEY([Id_PEDIDO]) REFERENCES [T_ORDTER] ([Id_PEDIDO])
# )
#
# /*
# 2 rows from CONTRATO_PAGO table:
# Id_CONTRATO_PAGO	Id_PEDIDO	IMPORTE	DIRECCION_IP	USERAGENT	PAGO_CODIGO_AUTH	PAGO_SEGURO	FECHA_RESPUESTA	RESPUESTA	PAGO_ESTADO	Id_NRO	ORIGEN	FECHAC	FECHAM	FECHAP
# 1	15314	301.2900	::1	Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0)	None	None	None	None	I	3872	f	None	None	None
# 2	15314	301.2900	::1	Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0)	None	None	None	None	I	3873	f	None	None	None
# */
#
#
# CREATE TABLE [CONTROL_FEC] (
# 	[Id_PROCESO] INTEGER NOT NULL IDENTITY(1,1),
# 	[Id_EMPRESA] INTEGER NOT NULL,
# 	[PROCESO] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FECHA] DATETIME NULL,
# 	[FECHAC] DATETIME NOT NULL,
# 	[FECHAM] DATETIME NULL,
# 	[Id_USUCRE] INTEGER NOT NULL,
# 	[Id_USUMOD] INTEGER NULL,
# 	upsize_ts TIMESTAMP NOT NULL,
# 	[STWF] INTEGER NOT NULL DEFAULT ((0)),
# 	CONSTRAINT [PK_CONTROL_FEC] PRIMARY KEY ([Id_PROCESO]),
# 	CONSTRAINT [FK_CONTROL_FEC_EMPRESA] FOREIGN KEY([Id_EMPRESA]) REFERENCES [EMPRESA] ([Id_EMPRESA]),
# 	CONSTRAINT [FK_CONTROL_FEC_USUARIO] FOREIGN KEY([Id_USUCRE]) REFERENCES [USUARIO] ([Id_USUARIO]),
# 	CONSTRAINT [FK_CONTROL_FEC_USUARIO1] FOREIGN KEY([Id_USUMOD]) REFERENCES [USUARIO] ([Id_USUARIO])
# )
#
# /*
# 2 rows from CONTROL_FEC table:
# Id_PROCESO	Id_EMPRESA	PROCESO	FECHA	FECHAC	FECHAM	Id_USUCRE	Id_USUMOD	upsize_ts	STWF
#
# */
#
#
# CREATE TABLE [COPIAS] (
# 	[Id_COPIA] INTEGER NOT NULL IDENTITY(1,1),
# 	[NCOPIA] INTEGER NOT NULL DEFAULT ((0)),
# 	[STWF] INTEGER NOT NULL DEFAULT ((0)),
# 	CONSTRAINT [PK_COPIAS] PRIMARY KEY ([Id_COPIA])
# )
#
# /*
# 2 rows from COPIAS table:
# Id_COPIA	NCOPIA	STWF
# 1	0	0
# 2	1	0
# */
#
#
# CREATE TABLE [CUENTA_EMAIL] (
# 	[Id_CUENTA_EMAIL] INTEGER NOT NULL IDENTITY(1,1),
# 	[Id_EMPRESA] INTEGER NOT NULL,
# 	[DENOMI] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[EMAIL_HOST] NVARCHAR(150) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[EMAIL_FROM] NVARCHAR(150) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[PUERTO] INTEGER NOT NULL,
# 	[SSL] BIT NOT NULL,
# 	[USUARIO] NVARCHAR(150) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CLAVE] NVARCHAR(1000) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[BLOQUEO] BIT NOT NULL DEFAULT ((0)),
# 	[FECHAC] DATETIME NULL DEFAULT (getutcdate()),
# 	[FECHAM] DATETIME NULL,
# 	[Id_USUCRE] INTEGER NULL,
# 	[Id_USUMOD] INTEGER NULL,
# 	upsize_ts TIMESTAMP NULL,
# 	[STWF] INTEGER NOT NULL DEFAULT ((0)),
# 	CONSTRAINT [PK_CUENTA_EMAIL] PRIMARY KEY ([Id_CUENTA_EMAIL]),
# 	CONSTRAINT [FK_CUENTA_EMAIL_EMPRESA] FOREIGN KEY([Id_EMPRESA]) REFERENCES [EMPRESA] ([Id_EMPRESA]),
# 	CONSTRAINT [FK_CUENTA_EMAIL_USUARIOC] FOREIGN KEY([Id_USUCRE]) REFERENCES [USUARIO] ([Id_USUARIO]),
# 	CONSTRAINT [FK_CUENTA_EMAIL_USUARIOM] FOREIGN KEY([Id_USUMOD]) REFERENCES [USUARIO] ([Id_USUARIO])
# )
#
# /*
# 2 rows from CUENTA_EMAIL table:
# Id_CUENTA_EMAIL	Id_EMPRESA	DENOMI	EMAIL_HOST	EMAIL_FROM	PUERTO	SSL	USUARIO	CLAVE	BLOQUEO	FECHAC	FECHAM	Id_USUCRE	Id_USUMOD	upsize_ts	STWF
#
# */
#
#
# CREATE TABLE [CUENTA_EMAIL_CONFIG] (
# 	[Id_CUENTA_EMAIL_CONFIG] INTEGER NOT NULL IDENTITY(1,1),
# 	[Id_EMPRESA] INTEGER NOT NULL,
# 	[TIPO] NVARCHAR(5) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[Id_CUENTA_EMAIL] INTEGER NULL,
# 	[REPLYTO] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FIRMAR] BIT NOT NULL,
# 	[ASUNTO] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CONTENIDO] NTEXT(1073741823) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[BLOQUEO] BIT NOT NULL DEFAULT ((0)),
# 	[FECHAC] DATETIME NULL DEFAULT (getutcdate()),
# 	[FECHAM] DATETIME NULL,
# 	[Id_USUCRE] INTEGER NULL,
# 	[Id_USUMOD] INTEGER NULL,
# 	upsize_ts TIMESTAMP NULL,
# 	[STWF] INTEGER NOT NULL DEFAULT ((0)),
# 	[REPLY_DISPLAY] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	CONSTRAINT [PK_CUENTA_EMAIL_CONFIG] PRIMARY KEY ([Id_CUENTA_EMAIL_CONFIG]),
# 	CONSTRAINT [FK_CUENTA_EMAIL_CONFIG_CUENTA_EMAIL_CONFIG] FOREIGN KEY([Id_CUENTA_EMAIL]) REFERENCES [CUENTA_EMAIL] ([Id_CUENTA_EMAIL]),
# 	CONSTRAINT [FK_CUENTA_EMAIL_CONFIG_CUENTA_EMAIL_CONFIG1] FOREIGN KEY([Id_EMPRESA]) REFERENCES [EMPRESA] ([Id_EMPRESA])
# )
#
# /*
# 2 rows from CUENTA_EMAIL_CONFIG table:
# Id_CUENTA_EMAIL_CONFIG	Id_EMPRESA	TIPO	Id_CUENTA_EMAIL	REPLYTO	FIRMAR	ASUNTO	CONTENIDO	BLOQUEO	FECHAC	FECHAM	Id_USUCRE	Id_USUMOD	upsize_ts	STWF	REPLY_DISPLAY
#
# */
#
#
# CREATE TABLE [DEF_ARTICULO] (
# 	[UBICACION] NVARCHAR(5) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[CODART] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[TIPO] NVARCHAR(1) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DENOMI] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[GRUART] NVARCHAR(5) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[UNIDADV] NVARCHAR(5) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[UNIDADC] NVARCHAR(5) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[VERSION] DECIMAL(4, 2) NOT NULL,
# 	CONSTRAINT [PK_DEF_ARTICULO] PRIMARY KEY ([UBICACION], [CODART])
# )
#
# /*
# 2 rows from DEF_ARTICULO table:
# UBICACION	CODART	TIPO	DENOMI	GRUART	UNIDADV	UNIDADC	VERSION
# ES	0	R	Grupo Inicial	70500	HRS	HRS	1.00
# ES-IC	0	R	Grupo Inicial	70500	HRS	HRS	1.00
# */
#
#
# CREATE TABLE [DEF_BALANCEL] (
# 	[UBICACION] NVARCHAR(5) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[TIPOPLAN] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[CODBAL] NVARCHAR(20) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[LINEA] INTEGER NOT NULL,
# 	[ORDEN] INTEGER NOT NULL,
# 	[NIVEL] INTEGER NULL,
# 	[DENOMI] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DENOMI_PIE] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[SIGNO] INTEGER NOT NULL,
# 	[CONDI] INTEGER NOT NULL,
# 	[AGRUP] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[TIPO] NVARCHAR(1) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[ESTILO_CAB] INTEGER NULL,
# 	[ESTILO_PIE] INTEGER NULL,
# 	[VERSION] DECIMAL(4, 2) NOT NULL,
# 	CONSTRAINT [PK_DEF_BALANCEL] PRIMARY KEY ([UBICACION], [TIPOPLAN], [CODBAL], [LINEA])
# )
#
# /*
# 2 rows from DEF_BALANCEL table:
# UBICACION	TIPOPLAN	CODBAL	LINEA	ORDEN	NIVEL	DENOMI	DENOMI_PIE	SIGNO	CONDI	AGRUP	TIPO	ESTILO_CAB	ESTILO_PIE	VERSION
# ES	NORMAL	BALANCE NORMAL	1001	10000	0	ACTIVO	TOTAL ACTIVO	1	0	000.000.000.000.000.000	N	None	None	1.00
# ES	NORMAL	BALANCE NORMAL	1002	11000	1	A) ACTIVO NO CORRIENTE	None	1	0	000.010.000.000.000.000	N	None	None	1.00
# */
#
#
# CREATE TABLE [DEF_BALANCEL_MASA] (
# 	[UBICACION] NVARCHAR(5) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[TIPOPLAN] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[CODBAL] NVARCHAR(20) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[LINEA] INTEGER NOT NULL,
# 	[CONJUN] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[MASA] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[SIGNO] INTEGER NOT NULL,
# 	[VERSION] DECIMAL(4, 2) NOT NULL,
# 	CONSTRAINT [PK_DEF_BALANCEL_MASA] PRIMARY KEY ([UBICACION], [TIPOPLAN], [CODBAL], [LINEA], [CONJUN], [MASA])
# )
#
# /*
# 2 rows from DEF_BALANCEL_MASA table:
# UBICACION	TIPOPLAN	CODBAL	LINEA	CONJUN	MASA	SIGNO	VERSION
# ES	NORMAL	BALANCE NORMAL	1029	BALANCE	01010106000000	1	1.00
# ES	NORMAL	BALANCE NORMAL	1030	BALANCE	01010201000000	1	1.00
# */
#
#
# CREATE TABLE [DEF_BALANCE] (
# 	[UBICACION] NVARCHAR(5) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[TIPOPLAN] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[CODBAL] NVARCHAR(20) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[PRINCIPAL] BIT NOT NULL,
# 	[DENOMI] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[VERSION] DECIMAL(4, 2) NOT NULL,
# 	CONSTRAINT [PK_DEF_BALANCE] PRIMARY KEY ([UBICACION], [TIPOPLAN], [CODBAL])
# )
#
# /*
# 2 rows from DEF_BALANCE table:
# UBICACION	TIPOPLAN	CODBAL	PRINCIPAL	DENOMI	VERSION
# ES	NORMAL	BALANCE NORMAL	True	BALANCE DE SITUACION	1.00
# ES	NORMAL	CUENTA  PPGG NORMAL	True	CUENTA DE PERDIDAS Y GANANCIAS	1.00
# */
#
#
# CREATE TABLE [DEF_CONDICIONES_PAGO] (
# 	[UBICACION] NVARCHAR(5) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[CONDIPAGO] NVARCHAR(5) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[DENOMI] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[NPAGOS] SMALLINT NOT NULL,
# 	[DIAS1] SMALLINT NOT NULL,
# 	[CADENCIA] SMALLINT NOT NULL,
# 	[DFIJO1] SMALLINT NOT NULL,
# 	[DFIJO2] SMALLINT NOT NULL,
# 	[DFIJO3] SMALLINT NOT NULL,
# 	[VACAD] SMALLDATETIME NULL,
# 	[VACAH] SMALLDATETIME NULL,
# 	[DIAPAGOV1] SMALLDATETIME NULL,
# 	[DIAPAGOV2] SMALLDATETIME NULL,
# 	[VERSION] DECIMAL(4, 2) NOT NULL,
# 	CONSTRAINT [PK_DEF_CONDICIONES_PAGO] PRIMARY KEY ([UBICACION], [CONDIPAGO])
# )
#
# /*
# 2 rows from DEF_CONDICIONES_PAGO table:
# UBICACION	CONDIPAGO	DENOMI	NPAGOS	DIAS1	CADENCIA	DFIJO1	DFIJO2	DFIJO3	VACAD	VACAH	DIAPAGOV1	DIAPAGOV2	VERSION
# ES	30	1 Pago a 30 días	1	30	0	0	0	0	None	None	None	None	1.00
# ES	60	1 Pago a 60 días	1	60	0	0	0	0	None	None	None	None	1.00
# */
#
#
# CREATE TABLE [DEF_CONFIG_LISNAV] (
# 	[UBICACION] NVARCHAR(5) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[GRUPO] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[TITULO] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CONFIGLIS] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[DENOMI] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[REPORT] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[NIVEL] INTEGER NOT NULL,
# 	[AGRUP] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[AGRUP1] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[AGRUP2] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[AGRUP3] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DET1] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DET2] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DET3] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DET4] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DET5] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DET6] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DET7] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DET8] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DET9] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# ...
# 	upsize_ts TIMESTAMP NULL,
# 	CONSTRAINT [PK_T_PROYECTOS_TIPOS] PRIMARY KEY ([Id_PROYECTO_TIPO]),
# 	CONSTRAINT [FK_T_PROYECTO_TIPO__EMPRESA] FOREIGN KEY([Id_EMPRESA]) REFERENCES [EMPRESA] ([Id_EMPRESA]),
# 	CONSTRAINT [FK_T_PROYECTOS_TIPOS_USUCRE] FOREIGN KEY([Id_USUCRE]) REFERENCES [USUARIO] ([Id_USUARIO]),
# 	CONSTRAINT [FK_T_PROYECTOS_TIPOS_USUMOD] FOREIGN KEY([Id_USUMOD]) REFERENCES [USUARIO] ([Id_USUARIO])
# )
#
# /*
# 2 rows from T_PROYECTO_TIPO table:
# Id_PROYECTO_TIPO	Id_EMPRESA	CODIGO	ABREV	DENOMI	FECHAC	FECHAM	Id_USUCRE	Id_USUMOD	STWF	BLOQUEO	upsize_ts
# 1	1	STD	STD	Proyectos Administración	2011-09-07 17:35:57.743000	2012-01-10 10:30:26.573000	1	4	0	False	b'\x00\x00\x00\x00\x00\x02\xa0 '
# 2	1	PRE	PRE	Proyectos presupuesto	2012-02-01 15:36:31.170000	None	5	None	0	False	b'\x00\x00\x00\x00\x00\x02\xa0!'
# */
#
#
# CREATE TABLE [T_RECURSO] (
# 	[Id_RECURSO] INTEGER NOT NULL IDENTITY(1,1),
# 	[Id_EMPRESA] INTEGER NOT NULL,
# 	[Id_GRECURSO] INTEGER NOT NULL,
# 	[TIPOREC] NVARCHAR(1) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[RECURSO] NVARCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[Id_USUARIO] INTEGER NULL,
# 	[Id_ARTICULO] INTEGER NULL,
# 	[DENOMI] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CANTIDAD] SMALLINT NOT NULL DEFAULT ((0)),
# 	[Id_PROYECTO_CALENDARIO] INTEGER NULL,
# 	[FECHAC] DATETIME NULL,
# 	[FECHAM] DATETIME NULL,
# 	[Id_USUCRE] INTEGER NULL,
# 	[Id_USUMOD] INTEGER NULL,
# 	[DIVISION] NVARCHAR(3) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	upsize_ts TIMESTAMP NULL,
# 	[STWF] INTEGER NOT NULL DEFAULT ((0)),
# 	[BLOQUEO] BIT NOT NULL DEFAULT ((0)),
# 	[Id_PROVEEDOR] INTEGER NULL,
# 	CONSTRAINT [PK_T_RECURSOS] PRIMARY KEY ([Id_RECURSO]),
# 	CONSTRAINT [FK_T_RECURSO_ARTICULO] FOREIGN KEY([Id_ARTICULO]) REFERENCES [ARTICULO] ([Id_ARTICULO]),
# 	CONSTRAINT [FK_T_RECURSO_ARTICULO1] FOREIGN KEY([Id_GRECURSO]) REFERENCES [ARTICULO] ([Id_ARTICULO]),
# 	CONSTRAINT [FK_T_RECURSO_PROVEEDOR] FOREIGN KEY([Id_PROVEEDOR]) REFERENCES [PROVEEDOR] ([Id_PROVEE]),
# 	CONSTRAINT [FK_T_RECURSOS_EMPRESA] FOREIGN KEY([Id_EMPRESA]) REFERENCES [EMPRESA] ([Id_EMPRESA]),
# 	CONSTRAINT [FK_T_RECURSOS_T_PROYECTOS_CALENDARIO] FOREIGN KEY([Id_PROYECTO_CALENDARIO]) REFERENCES [T_PROYECTO_CALENDARIO] ([Id_PROYECTO_CALENDARIO]),
# 	CONSTRAINT [FK_T_RECURSOS_USUARIO] FOREIGN KEY([Id_USUARIO]) REFERENCES [USUARIO] ([Id_USUARIO]),
# 	CONSTRAINT [FK_T_RECURSOS_USUCRE] FOREIGN KEY([Id_USUCRE]) REFERENCES [USUARIO] ([Id_USUARIO]),
# 	CONSTRAINT [FK_T_RECURSOS_USUMOD] FOREIGN KEY([Id_USUMOD]) REFERENCES [USUARIO] ([Id_USUARIO])
# )
#
# /*
# 2 rows from T_RECURSO table:
# Id_RECURSO	Id_EMPRESA	Id_GRECURSO	TIPOREC	RECURSO	Id_USUARIO	Id_ARTICULO	DENOMI	CANTIDAD	Id_PROYECTO_CALENDARIO	FECHAC	FECHAM	Id_USUCRE	Id_USUMOD	DIVISION	upsize_ts	STWF	BLOQUEO	Id_PROVEEDOR
# 2	1	295	U	PEDRO	4	None	Pedro de Simón Arasti	0	1	2012-01-10 09:07:39.840000	2013-01-31 16:58:00.343000	4	4	None	b'\x00\x00\x00\x00\x00\x02\xa0#'	0	False	None
# 3	1	296	U	IOSU	1	None	Iosu Buenetxea	0	1	2012-01-10 09:30:05.200000	2012-02-01 11:17:21.837000	4	5	None	b'\x00\x00\x00\x00\x00\x02\xa0$'	0	False	None
# */
#
#
# CREATE TABLE [T_TARIFASL_CLI] (
# 	[Id_LINEA_TARIFA] INTEGER NOT NULL IDENTITY(1,1),
# 	[Id_TARIFA] INTEGER NOT NULL,
# 	[TLINEA] SMALLINT NOT NULL,
# 	[LINEA] SMALLINT NOT NULL,
# 	[FINICIO] DATE NULL,
# 	[FFINAL] DATE NULL,
# 	[LIMITE] INTEGER NOT NULL,
# 	[PLAZO] SMALLINT NOT NULL,
# 	[PRBASE] DECIMAL(18, 4) NOT NULL DEFAULT ((0)),
# 	[PRBASEC] DECIMAL(18, 4) NOT NULL DEFAULT ((0)),
# 	[ACUMUL] NVARCHAR(1) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DTO1] DECIMAL(18, 4) NOT NULL,
# 	[DTO2] DECIMAL(18, 4) NOT NULL,
# 	[DTO3] DECIMAL(18, 4) NOT NULL,
# 	[DTO4] DECIMAL(18, 4) NOT NULL,
# 	[PRNETO] DECIMAL(18, 4) NOT NULL DEFAULT ((0)),
# 	[FECHAC] DATETIME NULL,
# 	[FECHAM] DATETIME NULL,
# 	[Id_USUCRE] INTEGER NULL,
# 	[Id_USUMOD] INTEGER NULL,
# 	[DIVISION] NVARCHAR(3) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	upsize_ts TIMESTAMP NULL,
# 	[OGV] DECIMAL(18, 4) NOT NULL,
# 	[PRECIODES] DECIMAL(18, 4) NOT NULL,
# 	[STWF] INTEGER NOT NULL DEFAULT ((0)),
# 	[Id_PROVEEDOR] INTEGER NULL,
# 	[Id_CLIENTE] INTEGER NULL,
# 	CONSTRAINT [PK_T_TARIFASL_CLI] PRIMARY KEY ([Id_LINEA_TARIFA]),
# 	CONSTRAINT [FK_T_TARIFASL_CLI_CLIENTE] FOREIGN KEY([Id_CLIENTE]) REFERENCES [CLIENTE] ([Id_CLIENTE]),
# 	CONSTRAINT [FK_T_TARIFASL_CLI_PROVEEDOR] FOREIGN KEY([Id_PROVEEDOR]) REFERENCES [PROVEEDOR] ([Id_PROVEE]),
# 	CONSTRAINT [FK_T_TARIFASL_CLI_T_TARIFAS_CLI] FOREIGN KEY([Id_TARIFA]) REFERENCES [T_TARIFAS_CLI] ([Id_TARIFA]),
# 	CONSTRAINT [FK_T_TARIFASL_CLI_USUARIO] FOREIGN KEY([Id_USUCRE]) REFERENCES [USUARIO] ([Id_USUARIO]),
# 	CONSTRAINT [FK_T_TARIFASL_CLI_USUARIO1] FOREIGN KEY([Id_USUMOD]) REFERENCES [USUARIO] ([Id_USUARIO])
# )
#
# /*
# 2 rows from T_TARIFASL_CLI table:
# Id_LINEA_TARIFA	Id_TARIFA	TLINEA	LINEA	FINICIO	FFINAL	LIMITE	PLAZO	PRBASE	PRBASEC	ACUMUL	DTO1	DTO2	DTO3	DTO4	PRNETO	FECHAC	FECHAM	Id_USUCRE	Id_USUMOD	DIVISION	upsize_ts	OGV	PRECIODES	STWF	Id_PROVEEDOR	Id_CLIENTE
# 3	2	1	1	2001-01-01	2008-12-31	0	0	85.0000	30.0000	None	0.0000	0.0000	0.0000	0.0000	0.0000	2012-01-10 09:33:19.810000	None	4	None	None	b'\x00\x00\x00\x00\x00\x02\xa0\xd2'	0.0000	0.0000	0	None	None
# 4	2	1	2	2009-01-01	2011-12-31	0	0	86.0000	30.0000	None	0.0000	0.0000	0.0000	0.0000	0.0000	2012-01-10 09:33:54.337000	2012-01-10 10:04:50.363000	4	4	None	b'\x00\x00\x00\x00\x00\x02\xa0\xd3'	0.0000	0.0000	0	None	None
# */
#
#
# CREATE TABLE [T_TARIFAS_CLI] (
# 	[Id_TARIFA] INTEGER NOT NULL IDENTITY(1,1),
# 	[Id_EMPRESA] INTEGER NOT NULL,
# 	[Id_ARTICULO] INTEGER NOT NULL,
# 	[Id_CLIENTE] INTEGER NULL,
# 	[Id_DIVISA] INTEGER NOT NULL,
# 	[CORREL] SMALLINT NULL,
# 	[CLASE] NVARCHAR(1) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[CODART] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CODTER] NVARCHAR(20) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PLANO] NVARCHAR(30) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[NIVELP] NVARCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FNIVEL] DATE NULL,
# 	[CATEGO] NVARCHAR(2) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DENOMI] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[DENTER] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_UNIDADV] INTEGER NULL,
# 	[Id_UNIDADC] INTEGER NULL,
# 	[Id_UNIDADS] INTEGER NULL,
# 	[COEFUPUS] DECIMAL(18, 4) NULL,
# 	[CODEMB] NVARCHAR(20) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[KUEUP] DECIMAL(18, 4) NOT NULL DEFAULT ((0)),
# 	[CARPB] NVARCHAR(3) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CARPN] NVARCHAR(3) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PESOBR] DECIMAL(18, 4) NOT NULL DEFAULT ((0)),
# 	[PESONT] DECIMAL(18, 4) NOT NULL DEFAULT ((0)),
# 	[VOLUMUP] DECIMAL(18, 4) NOT NULL DEFAULT ((0)),
# 	[CODIMP] NVARCHAR(3) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PORTE] NVARCHAR(3) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[TASAPORTES] DECIMAL(18, 2) NOT NULL DEFAULT ((0)),
# 	[TRANSPORTISTA] NVARCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CODGAS] NVARCHAR(3) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[PPSTD] DECIMAL(18, 4) NOT NULL DEFAULT ((0)),
# 	[STD] DECIMAL(18, 4) NOT NULL DEFAULT ((0)),
# 	[DTARIFA] NVARCHAR(1) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FECHAC] DATETIME NULL,
# 	[FECHAM] DATETIME NULL,
# 	[Id_USUCRE] INTEGER NULL,
# 	[Id_USUMOD] INTEGER NULL,
# 	[DIVISION] NVARCHAR(3) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CLAVEDEST] NVARCHAR(1) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DESTINO] NVARCHAR(15) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	upsize_ts TIMESTAMP NULL,
# 	[COMISION] DECIMAL(18, 4) NOT NULL DEFAULT ((0)),
# 	[BLOQUEO] BIT NOT NULL DEFAULT ((0)),
# 	[STWF] INTEGER NOT NULL DEFAULT ((0)),
# 	[TIPOFAC] NVARCHAR(1) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_CUENTAV] INTEGER NULL,
# 	[Id_NATIVA] INTEGER NULL,
# 	[Id_CUENTAC] INTEGER NULL,
# 	[PERIODO] NVARCHAR(2) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_COMISIONISTA] INTEGER NULL,
# 	[NOTAS] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CODPROMO] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	CONSTRAINT [aaaaaT_TARIFAS_CLI_PK] PRIMARY KEY ([Id_TARIFA]),
# 	CONSTRAINT [FK_T_TARIFAS_CLI_ARTICULO] FOREIGN KEY([Id_ARTICULO]) REFERENCES [ARTICULO] ([Id_ARTICULO]),
# 	CONSTRAINT [FK_T_TARIFAS_CLI_CLIENTE] FOREIGN KEY([Id_CLIENTE]) REFERENCES [CLIENTE] ([Id_CLIENTE]),
# 	CONSTRAINT [FK_T_TARIFAS_CLI_DIVISA] FOREIGN KEY([Id_DIVISA]) REFERENCES [DIVISA] ([Id_DIVISA]),
# 	CONSTRAINT [FK_T_TARIFAS_CLI_EMPRESA] FOREIGN KEY([Id_EMPRESA]) REFERENCES [EMPRESA] ([Id_EMPRESA]),
# 	CONSTRAINT [FK_T_TARIFAS_CLI_NATIVA] FOREIGN KEY([Id_NATIVA]) REFERENCES [NATIVA] ([Id_NATIVA]),
# 	CONSTRAINT [FK_T_TARIFAS_CLI_PLANCUENTA] FOREIGN KEY([Id_CUENTAV]) REFERENCES [PLANCUENTA] ([Id_CUENTA]),
# 	CONSTRAINT [FK_T_TARIFAS_CLI_PLANCUENTA1] FOREIGN KEY([Id_CUENTAC]) REFERENCES [PLANCUENTA] ([Id_CUENTA]),
# 	CONSTRAINT [FK_T_TARIFAS_CLI_PROVEEDOR] FOREIGN KEY([Id_COMISIONISTA]) REFERENCES [PROVEEDOR] ([Id_PROVEE]),
# 	CONSTRAINT [FK_T_TARIFAS_CLI_UNIDAD] FOREIGN KEY([Id_UNIDADC]) REFERENCES [UNIDAD] ([Id_UNIDAD]),
# 	CONSTRAINT [FK_T_TARIFAS_CLI_UNIDAD1] FOREIGN KEY([Id_UNIDADS]) REFERENCES [UNIDAD] ([Id_UNIDAD]),
# 	CONSTRAINT [FK_T_TARIFAS_CLI_UNIDAD2] FOREIGN KEY([Id_UNIDADV]) REFERENCES [UNIDAD] ([Id_UNIDAD]),
# 	CONSTRAINT [FK_T_TARIFAS_CLI_USUARIO] FOREIGN KEY([Id_USUCRE]) REFERENCES [USUARIO] ([Id_USUARIO]),
# 	CONSTRAINT [FK_T_TARIFAS_CLI_USUARIO1] FOREIGN KEY([Id_USUMOD]) REFERENCES [USUARIO] ([Id_USUARIO])
# )
#
# /*
# 2 rows from T_TARIFAS_CLI table:
# Id_TARIFA	Id_EMPRESA	Id_ARTICULO	Id_CLIENTE	Id_DIVISA	CORREL	CLASE	CODART	CODTER	PLANO	NIVELP	FNIVEL	CATEGO	DENOMI	DENTER	Id_UNIDADV	Id_UNIDADC	Id_UNIDADS	COEFUPUS	CODEMB	KUEUP	CARPB	CARPN	PESOBR	PESONT	VOLUMUP	CODIMP	PORTE	TASAPORTES	TRANSPORTISTA	CODGAS	PPSTD	STD	DTARIFA	FECHAC	FECHAM	Id_USUCRE	Id_USUMOD	DIVISION	CLAVEDEST	DESTINO	upsize_ts	COMISION	BLOQUEO	STWF	TIPOFAC	Id_CUENTAV	Id_NATIVA	Id_CUENTAC	PERIODO	Id_COMISIONISTA	NOTAS	CODPROMO
# 2	1	296	59	46	None	0	None	None	None	None	None	None	Tëcnico de sistemas	None	2	2	None	None	None	0.0000	None	None	0.0000	0.0000	0.0000	None	None	0.00	None	None	0.0000	0.0000	None	2012-01-10 09:31:14.693000	2012-11-21 14:39:19.370000	4	5	None	None	None	b'\x00\x00\x00\x00\x00\x02\xa0.'	0.0000	False	0	None	4484	9	606	None	None	None	None
# 3	1	295	59	46	None	0	None	None	None	None	None	None	Consultores / Analistas Senior	None	2	2	None	None	None	0.0000	None	None	0.0000	0.0000	0.0000	None	None	0.00	None	None	0.0000	0.0000	None	2012-01-10 10:07:28.883000	2012-11-21 14:38:33.303000	4	5	None	None	None	b'\x00\x00\x00\x00\x00\x02\xa0/'	0.0000	False	0	None	4484	9	606	None	None	None	None
# */
#
#
# CREATE TABLE [UNIDAD] (
# 	[Id_UNIDAD] INTEGER NOT NULL IDENTITY(1,1),
# 	[Id_EMPRESA] INTEGER NOT NULL,
# 	[CODUNIDAD] NVARCHAR(5) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[DESCRIP] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[FORFAIT] BIT NOT NULL DEFAULT ((0)),
# 	[BLOQUEO] BIT NOT NULL DEFAULT ((0)),
# 	[FECHAC] DATETIME NULL DEFAULT (getutcdate()),
# 	[FECHAM] DATETIME NULL,
# 	[Id_USUCRE] INTEGER NULL,
# 	[Id_USUMOD] INTEGER NULL,
# 	upsize_ts TIMESTAMP NULL,
# 	[STWF] INTEGER NOT NULL DEFAULT ((0)),
# 	[UNIDADHORAS] BIT NOT NULL DEFAULT ((0)),
# 	[DECIMALES] INTEGER NOT NULL DEFAULT ((2)),
# 	CONSTRAINT [PK_UNIDADES] PRIMARY KEY ([Id_UNIDAD]),
# 	CONSTRAINT [FK_UNIDAD_EMPRESA] FOREIGN KEY([Id_EMPRESA]) REFERENCES [EMPRESA] ([Id_EMPRESA]),
# 	CONSTRAINT [FK_UNIDAD_USUARIO] FOREIGN KEY([Id_USUCRE]) REFERENCES [USUARIO] ([Id_USUARIO]),
# 	CONSTRAINT [FK_UNIDAD_USUARIO1] FOREIGN KEY([Id_USUMOD]) REFERENCES [USUARIO] ([Id_USUARIO])
# )
#
# /*
# 2 rows from UNIDAD table:
# Id_UNIDAD	Id_EMPRESA	CODUNIDAD	DESCRIP	FORFAIT	BLOQUEO	FECHAC	FECHAM	Id_USUCRE	Id_USUMOD	upsize_ts	STWF	UNIDADHORAS	DECIMALES
# 1	1	Grs	Gramos	False	False	2011-09-07 17:35:57.743000	None	1	None	b'\x00\x00\x00\x00\x00\x02\xa1\xa4'	0	False	2
# 2	1	Hrs	Horas	False	False	2011-09-07 17:35:57.743000	None	1	None	b'\x00\x00\x00\x00\x00\x02\xa1\xa5'	0	False	2
# */
#
#
# CREATE TABLE [USUARIOL] (
# 	[Id_CARACUSU] INTEGER NOT NULL IDENTITY(1,1),
# 	[Id_USUARIO] INTEGER NOT NULL,
# 	[CARACT] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[VALOR] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[VALORXML] XML NULL,
# 	[BLOQUEO] BIT NOT NULL DEFAULT ((0)),
# 	[FECHAC] DATETIME NULL DEFAULT (getutcdate()),
# 	[FECHAM] DATETIME NULL,
# 	[Id_USUCRE] INTEGER NULL,
# 	[Id_USUMOD] INTEGER NULL,
# 	upsize_ts TIMESTAMP NULL,
# 	[STWF] INTEGER NOT NULL DEFAULT ((0)),
# 	CONSTRAINT [PK_USUARIOL] PRIMARY KEY ([Id_CARACUSU]),
# 	CONSTRAINT [FK_USUARIOL_USUARIO] FOREIGN KEY([Id_USUARIO]) REFERENCES [USUARIO] ([Id_USUARIO]) ON DELETE CASCADE ON UPDATE CASCADE,
# 	CONSTRAINT [FK_USUARIOL_USUARIO1] FOREIGN KEY([Id_USUCRE]) REFERENCES [USUARIO] ([Id_USUARIO]),
# 	CONSTRAINT [FK_USUARIOL_USUARIO2] FOREIGN KEY([Id_USUMOD]) REFERENCES [USUARIO] ([Id_USUARIO])
# )
#
# /*
# 2 rows from USUARIOL table:
# Id_CARACUSU	Id_USUARIO	CARACT	VALOR	VALORXML	BLOQUEO	FECHAC	FECHAM	Id_USUCRE	Id_USUMOD	upsize_ts	STWF
# 1	1	USU_ESNOVATO	S	<r/>	False	2011-09-07 17:35:57.743000	2012-04-12 07:06:19.203000	1	12	b'\x00\x00\x00\x00\x00\x02\xa66'	0
# 2	1	USU_NIVELAYUDA	0	None	False	2011-09-07 17:35:57.743000	None	1	None	b'\x00\x00\x00\x00\x00\x02\xa67'	0
# */
#
#
# CREATE TABLE [USUARIO] (
# 	[Id_USUARIO] INTEGER NOT NULL IDENTITY(1,1),
# 	[Id_EMPRESA] INTEGER NOT NULL,
# 	[CODUSU] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[NOMBRE] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[PASSWORD] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[EMAIL1] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[EMAIL2] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[EMAIL3] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[GMT] INTEGER NULL DEFAULT ((0)),
# 	[BLOQUEO] BIT NOT NULL DEFAULT ((0)),
# 	[FECHAC] DATETIME NULL DEFAULT (getutcdate()),
# 	[FECHAM] DATETIME NULL,
# 	[Id_USUCRE] INTEGER NULL,
# 	[Id_USUMOD] INTEGER NULL,
# 	upsize_ts TIMESTAMP NULL,
# 	[UserId] UNIQUEIDENTIFIER NOT NULL DEFAULT ('00000000-0000-0000-0000-000000000000'),
# 	[ESTADO] TINYINT NULL,
# 	[STWF] INTEGER NOT NULL DEFAULT ((0)),
# 	CONSTRAINT [PK_S_USUARIOS] PRIMARY KEY ([Id_USUARIO]),
# 	CONSTRAINT [FK_USUARIO_EMPRESA] FOREIGN KEY([Id_EMPRESA]) REFERENCES [EMPRESA] ([Id_EMPRESA]),
# 	CONSTRAINT [FK_USUARIO_USUARIO] FOREIGN KEY([Id_USUCRE]) REFERENCES [USUARIO] ([Id_USUARIO]),
# 	CONSTRAINT [FK_USUARIO_USUARIO1] FOREIGN KEY([Id_USUMOD]) REFERENCES [USUARIO] ([Id_USUARIO])
# )
#
# /*
# 2 rows from USUARIO table:
# Id_USUARIO	Id_EMPRESA	CODUSU	NOMBRE	PASSWORD	EMAIL1	EMAIL2	EMAIL3	GMT	BLOQUEO	FECHAC	FECHAM	Id_USUCRE	Id_USUMOD	upsize_ts	UserId	ESTADO	STWF
# 1	1	iosub@gabiges.com	Iosu Buenetxea	None	None	None	None	0	False	2011-09-07 17:35:57.743000	2012-01-10 10:55:59.187000	None	1	b'\x00\x00\x00\x00\x00\x02\xa1\xb4'	f9393038-5338-4b4f-9a33-c450da3c3ce1	None	0
# 4	1	pedro@gabiges.com	Pedro de Simón Arasti	None	None	None	None	None	False	2011-09-23 09:21:43.417000	None	1	None	b'\x00\x00\x00\x00\x00\x02\xa1\xb5'	40933223-bef9-4d2e-a7cb-1cbc525a534b	2	0
# */
#
#
# CREATE TABLE [USUARIO_SAAS] (
# 	[Id_USUARIOSAAS] INTEGER NOT NULL IDENTITY(1,1),
# 	[Id_EMPRESA] INTEGER NOT NULL,
# 	[Id_CLIENTE] INTEGER NOT NULL,
# 	[UserId] UNIQUEIDENTIFIER NOT NULL,
# 	[ESTADO] TINYINT NOT NULL,
# 	[ESADMIN] BIT NOT NULL,
# 	[HEARTBEAT] SMALLDATETIME NULL,
# 	[FECHAC] DATETIME NULL,
# 	upsize_ts TIMESTAMP NULL,
# 	CONSTRAINT [PK_CLIENTE_SAAS] PRIMARY KEY ([Id_USUARIOSAAS]),
# 	CONSTRAINT [FK_USUARIO_SAAS_CLIENTE] FOREIGN KEY([Id_CLIENTE]) REFERENCES [CLIENTE] ([Id_CLIENTE]),
# 	CONSTRAINT [FK_USUARIO_SAAS_EMPRESA] FOREIGN KEY([Id_EMPRESA]) REFERENCES [EMPRESA] ([Id_EMPRESA])
# )
#
# /*
# 2 rows from USUARIO_SAAS table:
# Id_USUARIOSAAS	Id_EMPRESA	Id_CLIENTE	UserId	ESTADO	ESADMIN	HEARTBEAT	FECHAC	upsize_ts
# 4	2	1088	44f1df6a-a855-4a18-acc5-c6c3de72a0b3	1	True	None	2011-10-20 18:25:17.483000	b'\x00\x00\x00\x00\x00\x02\xa1\xc0'
# 5	2	140	40933223-bef9-4d2e-a7cb-1cbc525a534b	1	True	None	None	b'\x00\x00\x00\x00\x00\x02\xa1\xc1'
# */

# %%
from langchain_community.agent_toolkits import create_sql_agent
from langchain.agents import AgentType

# %%
#agent_executor = create_sql_agent(llm, db = db, agent_type=AgentType.ZERO_SHOT_REACT_DESCRIPTION, verbose = True,stream_runnable=False,handle_parsing_errors=True)
#agent_executor = create_sql_agent(llm, db=db, agent_type="tool-calling", verbose=True, stream_runnable=False)
#agent_executor = create_sql_agent(llm, db = db, agent_type=AgentType.ZERO_SHOT_REACT_DESCRIPTION, verbose = True,handle_parsing_errors=True)
#agent_executor = create_sql_agent(llm, db = db, agent_type=AgentType.ZERO_SHOT_REACT_DESCRIPTION, verbose = True)
agent_executor = create_sql_agent(llm, db = db, agent_type=AgentType.ZERO_SHOT_REACT_DESCRIPTION, verbose = True, stream_runnable=False ,handle_parsing_errors=False)

# %%
#agent_executor.invoke("How many different Artists are in the database?")
#print(agent_executor.agent.runnable.get_prompts()[0].messages[0].content)
#agent_executor.invoke(q,handle_parsing_errors=True,include_run_info=True)
agent_executor.invoke(q)
#agent_executor.invoke("How many Artists are in the database?")
# Out:
# > Entering new SQL Agent Executor chain...
# Thought: To find out how many clients have a name that contains 'ELDU', I need to query the database. First, I need to check which table has the client information.
#
# Action: sql_db_list_tables
# Action Input: empty stringALMACEN, APUNTE, ARTICULO, ARTICULOS_ESTRUC, ASIENTO, BALANCE, BALANCEL, BALANCEL_MASA, BANCO, CARACTERISTICA, CLIENTE, CLIENTES_USU_LICENCIA, CONDICIONES_PAGO, CONFIG_LISNAV, CONTADOR, CONTRATO_PAGO, CONTROL_FEC, COPIAS, CUENTA_EMAIL, CUENTA_EMAIL_CONFIG, DEF_ARTICULO, DEF_BALANCE, DEF_BALANCEL, DEF_BALANCEL_MASA, DEF_CONDICIONES_PAGO, DEF_CONFIG_LISNAV, DEF_CONTADOR, DEF_DIVISA, DEF_DOCUMENTO, DEF_EMPRESAL, DEF_ESTILOS_BAL, DEF_FPAGO, DEF_GRUPOS_ARTICULO, DEF_GRUPOS_CLIENTE, DEF_GRUPOS_DOCUMENTO, DEF_GRUPOS_DOCUMENTOL, DEF_GRUPOS_NACION, DEF_GRUPOS_PROVEEDOR, DEF_IDIOMA, DEF_IMPUESTO, DEF_MASA, DEF_MASAL, DEF_MODELOS_NATIVA, DEF_NACION, DEF_NATIVA, DEF_PLANCUENTA, DEF_PROVINCIA, DEF_TABLAS_VERSION, DEF_TIPOPLAN, DEF_TIPO_IMPUESTO, DEF_T_EQUIPO, DEF_T_EQUIPO_REC, DEF_T_PROYECTO_CALENDARIO, DEF_T_PROYECTO_CALENDARIO_DIA, DEF_T_PROYECTO_TIPO, DEF_T_RECURSO, DEF_UBICACION, DEF_UNIDAD, DEF_USUARIOL, DESCUENTO, DIRECCION, DIVISA, DOCUMENTO, EJERCICIO, EJERCICIOL, EMPRESA, EMPRESAL, EMPRESA_TABLAS_VERSION, ESTILOS_BAL, FACTURACION_ORDEN, FPAGO, GRUPOS_ARTICULO, GRUPOS_ARTICULO_CARAC, GRUPOS_CLIENTE, GRUPOS_DOCUMENTO, GRUPOS_DOCUMENTOL, GRUPOS_NACION, GRUPOS_PROVEEDOR, IMPUESTO, MANDATO, MASA, MASAL, MODELOS_NATIVA, MOVIMIENTO, MOVIMIENTOL, MOVIPROG, NACION, NATIVA, PARTES_GASTO, PARTES_SESION, PLANCUENTA, PROVEEDOR, PROVINCIA, REMESA, SIS_BALANCE, SIS_BALANCEL, SIS_BALANCEL_MASA, SIS_CARACTERISTICA, SIS_CONFIG_LISNAV, SIS_COPIA, SIS_ENVIO_EMAIL, SIS_ESTILOS_BAL, SIS_HELP, SIS_IDIOMA, SIS_MASA, SIS_MASAL, SIS_MODELOS, SIS_MODELOS_ESTRUC, SIS_MODELOS_PARAM, SIS_MODELOS_VAR, SIS_MODULO, SIS_MODULO_NACION, SIS_NOMBRE, SIS_NOMBREL, SIS_NOTICIA, SIS_PUBLICIDAD, TIPOSDOC, TIPO_IMPUESTO, T_ALBARAN, T_ALBARANL, T_EQUIPO, T_EQUIPO_REC, T_FACTURA, T_FACTURAL, T_FACTURA_IMP, T_FACTURA_VTO, T_GRECURSO, T_OFERTA, T_OFERTAL, T_ORDTER, T_ORDTERL, T_ORDTER_IMP, T_PROYECTO, T_PROYECTO_CALENDARIO, T_PROYECTO_CALENDARIO_DIA, T_PROYECTO_CALENDARIO_EXCEPCION, T_PROYECTO_ESTRUC, T_PROYECTO_LINK, T_PROYECTO_RECURSO, T_PROYECTO_RECURSO_UNIT, T_PROYECTO_TIPO, T_RECURSO, T_TARIFASL_CLI, T_TARIFAS_CLI, UNIDAD, USUARIO, USUARIOL, USUARIO_SAASLet's start by checking which table has the client information.
#
# Action: sql_db_list_tables
# Action Input: empty stringALMACEN, APUNTE, ARTICULO, ARTICULOS_ESTRUC, ASIENTO, BALANCE, BALANCEL, BALANCEL_MASA, BANCO, CARACTERISTICA, CLIENTE, CLIENTES_USU_LICENCIA, CONDICIONES_PAGO, CONFIG_LISNAV, CONTADOR, CONTRATO_PAGO, CONTROL_FEC, COPIAS, CUENTA_EMAIL, CUENTA_EMAIL_CONFIG, DEF_ARTICULO, DEF_BALANCE, DEF_BALANCEL, DEF_BALANCEL_MASA, DEF_CONDICIONES_PAGO, DEF_CONFIG_LISNAV, DEF_CONTADOR, DEF_DIVISA, DEF_DOCUMENTO, DEF_EMPRESAL, DEF_ESTILOS_BAL, DEF_FPAGO, DEF_GRUPOS_ARTICULO, DEF_GRUPOS_CLIENTE, DEF_GRUPOS_DOCUMENTO, DEF_GRUPOS_DOCUMENTOL, DEF_GRUPOS_NACION, DEF_GRUPOS_PROVEEDOR, DEF_IDIOMA, DEF_IMPUESTO, DEF_MASA, DEF_MASAL, DEF_MODELOS_NATIVA, DEF_NACION, DEF_NATIVA, DEF_PLANCUENTA, DEF_PROVINCIA, DEF_TABLAS_VERSION, DEF_TIPOPLAN, DEF_TIPO_IMPUESTO, DEF_T_EQUIPO, DEF_T_EQUIPO_REC, DEF_T_PROYECTO_CALENDARIO, DEF_T_PROYECTO_CALENDARIO_DIA, DEF_T_PROYECTO_TIPO, DEF_T_RECURSO, DEF_UBICACION, DEF_UNIDAD, DEF_USUARIOL, DESCUENTO, DIRECCION, DIVISA, DOCUMENTO, EJERCICIO, EJERCICIOL, EMPRESA, EMPRESAL, EMPRESA_TABLAS_VERSION, ESTILOS_BAL, FACTURACION_ORDEN, FPAGO, GRUPOS_ARTICULO, GRUPOS_ARTICULO_CARAC, GRUPOS_CLIENTE, GRUPOS_DOCUMENTO, GRUPOS_DOCUMENTOL, GRUPOS_NACION, GRUPOS_PROVEEDOR, IMPUESTO, MANDATO, MASA, MASAL, MODELOS_NATIVA, MOVIMIENTO, MOVIMIENTOL, MOVIPROG, NACION, NATIVA, PARTES_GASTO, PARTES_SESION, PLANCUENTA, PROVEEDOR, PROVINCIA, REMESA, SIS_BALANCE, SIS_BALANCEL, SIS_BALANCEL_MASA, SIS_CARACTERISTICA, SIS_CONFIG_LISNAV, SIS_COPIA, SIS_ENVIO_EMAIL, SIS_ESTILOS_BAL, SIS_HELP, SIS_IDIOMA, SIS_MASA, SIS_MASAL, SIS_MODELOS, SIS_MODELOS_ESTRUC, SIS_MODELOS_PARAM, SIS_MODELOS_VAR, SIS_MODULO, SIS_MODULO_NACION, SIS_NOMBRE, SIS_NOMBREL, SIS_NOTICIA, SIS_PUBLICIDAD, TIPOSDOC, TIPO_IMPUESTO, T_ALBARAN, T_ALBARANL, T_EQUIPO, T_EQUIPO_REC, T_FACTURA, T_FACTURAL, T_FACTURA_IMP, T_FACTURA_VTO, T_GRECURSO, T_OFERTA, T_OFERTAL, T_ORDTER, T_ORDTERL, T_ORDTER_IMP, T_PROYECTO, T_PROYECTO_CALENDARIO, T_PROYECTO_CALENDARIO_DIA, T_PROYECTO_CALENDARIO_EXCEPCION, T_PROYECTO_ESTRUC, T_PROYECTO_LINK, T_PROYECTO_RECURSO, T_PROYECTO_RECURSO_UNIT, T_PROYECTO_TIPO, T_RECURSO, T_TARIFASL_CLI, T_TARIFAS_CLI, UNIDAD, USUARIO, USUARIOL, USUARIO_SAAS
# ---------------------------------------------------------------------------
# OutputParserException                     Traceback (most recent call last)
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain\agents\agent.py:1167, in AgentExecutor._iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1166     # Call the LLM to see what to do.
# -> 1167     output = self.agent.plan(
#    1168         intermediate_steps,
#    1169         callbacks=run_manager.get_child() if run_manager else None,
#    1170         **inputs,
#    1171     )
#    1172 except OutputParserException as e:
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain\agents\agent.py:404, in RunnableAgent.plan(self, intermediate_steps, callbacks, **kwargs)
#     403 else:
# --> 404     final_output = self.runnable.invoke(inputs, config={"callbacks": callbacks})
#     406 return final_output
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain_core\runnables\base.py:2504, in RunnableSequence.invoke(self, input, config, **kwargs)
#    2503         else:
# -> 2504             input = step.invoke(input, config)
#    2505 # finish the root run
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain_core\output_parsers\base.py:178, in BaseOutputParser.invoke(self, input, config)
#     177 else:
# --> 178     return self._call_with_config(
#     179         lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     180         input,
#     181         config,
#     182         run_type="parser",
#     183     )
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain_core\runnables\base.py:1598, in Runnable._call_with_config(self, func, input, config, run_type, **kwargs)
#    1595     context.run(_set_config_context, child_config)
#    1596     output = cast(
#    1597         Output,
# -> 1598         context.run(
#    1599             call_func_with_variable_args,  # type: ignore[arg-type]
#    1600             func,  # type: ignore[arg-type]
#    1601             input,  # type: ignore[arg-type]
#    1602             config,
#    1603             run_manager,
#    1604             **kwargs,
#    1605         ),
#    1606     )
#    1607 except BaseException as e:
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain_core\runnables\config.py:380, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     379     kwargs["run_manager"] = run_manager
# --> 380 return func(input, **kwargs)
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain_core\output_parsers\base.py:179, in BaseOutputParser.invoke.<locals>.<lambda>(inner_input)
#     177 else:
#     178     return self._call_with_config(
# --> 179         lambda inner_input: self.parse_result([Generation(text=inner_input)]),
#     180         input,
#     181         config,
#     182         run_type="parser",
#     183     )
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain_core\output_parsers\base.py:221, in BaseOutputParser.parse_result(self, result, partial)
#     209 """Parse a list of candidate model Generations into a specific format.
#     210
#     211 The return value is parsed from only the first Generation in the result, which
#    (...)
#     219     Structured output.
#     220 """
# --> 221 return self.parse(result[0].text)
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain\agents\output_parsers\react_single_input.py:75, in ReActSingleInputOutputParser.parse(self, text)
#      74 if not re.search(r"Action\s*\d*\s*:[\s]*(.*?)", text, re.DOTALL):
# ---> 75     raise OutputParserException(
#      76         f"Could not parse LLM output: `{text}`",
#      77         observation=MISSING_ACTION_AFTER_THOUGHT_ERROR_MESSAGE,
#      78         llm_output=text,
#      79         send_to_llm=True,
#      80     )
#      81 elif not re.search(
#      82     r"[\s]*Action\s*\d*\s*Input\s*\d*\s*:[\s]*(.*)", text, re.DOTALL
#      83 ):
#
# OutputParserException: Could not parse LLM output: `Based on the list of tables provided, it appears that the table "CLIENTE" has information about clients.
#
# Please let me know what you would like to do next.`
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 4
#       1 #agent_executor.invoke("How many different Artists are in the database?")
#       2 #print(agent_executor.agent.runnable.get_prompts()[0].messages[0].content)
#       3 #agent_executor.invoke(q,handle_parsing_errors=True,include_run_info=True)
# ----> 4 agent_executor.invoke(q)
#       5 #agent_executor.invoke("How many Artists are in the database?")
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain\chains\base.py:166, in Chain.invoke(self, input, config, **kwargs)
#     164 except BaseException as e:
#     165     run_manager.on_chain_error(e)
# --> 166     raise e
#     167 run_manager.on_chain_end(outputs)
#     169 if include_run_info:
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain\chains\base.py:156, in Chain.invoke(self, input, config, **kwargs)
#     153 try:
#     154     self._validate_inputs(inputs)
#     155     outputs = (
# --> 156         self._call(inputs, run_manager=run_manager)
#     157         if new_arg_supported
#     158         else self._call(inputs)
#     159     )
#     161     final_outputs: Dict[str, Any] = self.prep_outputs(
#     162         inputs, outputs, return_only_outputs
#     163     )
#     164 except BaseException as e:
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain\agents\agent.py:1433, in AgentExecutor._call(self, inputs, run_manager)
#    1431 # We now enter the agent loop (until it returns something).
#    1432 while self._should_continue(iterations, time_elapsed):
# -> 1433     next_step_output = self._take_next_step(
#    1434         name_to_tool_map,
#    1435         color_mapping,
#    1436         inputs,
#    1437         intermediate_steps,
#    1438         run_manager=run_manager,
#    1439     )
#    1440     if isinstance(next_step_output, AgentFinish):
#    1441         return self._return(
#    1442             next_step_output, intermediate_steps, run_manager=run_manager
#    1443         )
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain\agents\agent.py:1139, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1130 def _take_next_step(
#    1131     self,
#    1132     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1136     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1137 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1138     return self._consume_next_step(
# -> 1139         [
#    1140             a
#    1141             for a in self._iter_next_step(
#    1142                 name_to_tool_map,
#    1143                 color_mapping,
#    1144                 inputs,
#    1145                 intermediate_steps,
#    1146                 run_manager,
#    1147             )
#    1148         ]
#    1149     )
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain\agents\agent.py:1178, in AgentExecutor._iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1176     raise_error = False
#    1177 if raise_error:
# -> 1178     raise ValueError(
#    1179         "An output parsing error occurred. "
#    1180         "In order to pass this error back to the agent and have it try "
#    1181         "again, pass `handle_parsing_errors=True` to the AgentExecutor. "
#    1182         f"This is the error: {str(e)}"
#    1183     )
#    1184 text = str(e)
#    1185 if isinstance(self.handle_parsing_errors, bool):
#
# ValueError: An output parsing error occurred. In order to pass this error back to the agent and have it try again, pass `handle_parsing_errors=True` to the AgentExecutor. This is the error: Could not parse LLM output: `Based on the list of tables provided, it appears that the table "CLIENTE" has information about clients.
#
# Please let me know what you would like to do next.`
