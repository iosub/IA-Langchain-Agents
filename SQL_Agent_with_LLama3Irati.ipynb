# %%
# !pip install langchain langchain_community ollama

# %%
from langchain_community.llms import Ollama

# %%
# = Ollama(model = "llama3")#,temperature=0.2)
llm = Ollama(model = "starcoder2:15b")#,temperature=0) #deepseek-coder-v2:latest  starcoder2:15b  

#qwen2:latest

# %%
for chunk in llm.stream("Hi how are you?"):
    print(chunk, end = "")
# Out:
# Hello, my name is Gregory. I am a programmer and web developer.
#
# - Hi there! I am Gregory - A Programmer - Web Developer
#
# <NAME>
# Software Developer
# Kid Coder

# %%
from langchain_community.utilities import SQLDatabase

# %%
conn_str = "mssql+pyodbc://gg:ostia@minipc/iatest?driver=ODBC+Driver+17+for+SQL+Server"
#conn_str = "mssql+pyodbc://gg:ostia@minipc/MSPLITEPRO_v3gg?driver=ODBC+Driver+17+for+SQL+Server"

#conn_str = "mssql+pyodbc://gg:ostia@minipc/korta?driver=ODBC+Driver+17+for+SQL+Server"

q="Cual ha sido las ventas del año pasado a los clientes"
q="Cual ha sido las ventas por año  a los clientes. Muéstrame el resultado en Json"
q="Cuál ha sido el cliente al que más le he vendido"
q="Cuál ha sido el artículo que pasa vendido"
q="Para la empresa con codigo 1, que TIPOREG=CF en la tabla de T_ORDTER. Qué necesidades tengo de de compra para los artículos el 21 de diciembre del 2020"
q="Para la empresa con codigo 1,  Qué necesidades de compra de cantidad de artículos tengo el 21 de diciembre del 2020, Teniendo en cuenta los pedidos que estan en la tabla T_ORDTER con TIPOREG=CF y su stock que esta en la tabla T_STOCKS"
q="Para la empresa con codigo 1,  Qué necesidades de compra de cantidad de artículos tengo el 21 de diciembre del 2020, Teniendo en cuenta los pedidos que estan en la tabla T_ORDTER con TIPOREG=CF, su stock que esta en la tabla T_STOCKS y las ordenes de fabricacion que estan en T_ORDFAB y T_ORDFABM con TIPOREG=F" 
q="Cuántos Clientes hay?"
#q="Cuántos Clientes hay con El nombre que contenga ELDU ?"
#q="Cuántas facturas hay"
#db = SQLDatabase.from_uri(conn_str) #("sqlite:///Chinook.db")
#def __init__(
 #       self,
 #       engine: Engine,
 #       schema: Optional[str] = None,
 #       metadata: Optional[MetaData] = None,
 #       ignore_tables: Optional[List[str]] = None,
 #       include_tables: Optional[List[str]] = None,
 #       sample_rows_in_table_info: int = 3,
 #       indexes_in_table_info: bool = False,
 #       custom_table_info: Optional[dict] = None,
 #       view_support: bool = False,
 #       max_string_length: int = 300,
 #       lazy_table_reflection: bool = False,
 #   ):
 #       metadata: Optional[MetaData] = None,
 #       ignore_tables: Optional[List[str]] = None,
 #       include_tables: Optional[List[str]] = None,
 #       sample_rows_in_table_info: int = 3,
 #       indexes_in_table_info: bool = False,
 #       custom_table_info: Optional[dict] = None,
 #       view_support: bool = False,
 #       max_string_length: int = 300,
 #       lazy_table_reflection: bool = False,

#tables=["T_FACTURAS","T_CLIENTES","T_EMPRESA"]
#db111 = SQLDatabase.from_uri(conn_str,include_tables=tables,sample_rows_in_table_info = 0 )
db = SQLDatabase.from_uri(conn_str,sample_rows_in_table_info = 2)#,lazy_table_reflection=True)

#db = SQLDatabase.from_uri("sqlite:///chinook.db", sample_rows_in_table_info = 3)

# %%
db.get_usable_table_names()
# Out:
# ['CLIENTE', 'T_EQUIPO', 'T_FACTURA']

# %%
print(db.table_info)
# Out:
# CREATE TABLE [CLIENTE] (
# 	[Id_CLIENTE] INTEGER NOT NULL IDENTITY(1,1),
# 	[Id_EMPRESA] INTEGER NOT NULL,
# 	[CODCLI] NVARCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[Id_GRUCLI] INTEGER NOT NULL,
# 	[Id_DIVISA] INTEGER NOT NULL,
# 	[CIF] NVARCHAR(20) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[DENOMI] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[CONTACTO] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DIRECC] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CODPOS] NVARCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[LOCALIDAD] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_PAIS] INTEGER NULL,
# 	[Id_PROVINCIA] INTEGER NULL,
# 	[GMT] INTEGER NULL,
# 	[TEL] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[TEL2] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FAX] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[WWW] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[EMAIL1] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[EMAIL2] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[EMAIL3] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[SREFER] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[NREFER] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_GRUPDOC] INTEGER NULL,
# 	[Id_CUENTA] INTEGER NULL,
# 	[Id_NATIVA] INTEGER NULL,
# 	[Id_FPAGO] INTEGER NULL,
# 	[Id_CONDIPAGO] INTEGER NULL,
# 	[Id_BANCO] INTEGER NULL,
# 	[SWIFT] NVARCHAR(11) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[IBAN] NVARCHAR(40) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_DTO] INTEGER NULL,
# 	[Id_REC] INTEGER NULL,
# 	[LIMCRED] DECIMAL(18, 2) NULL,
# 	[FACELEC] BIT NOT NULL,
# 	[BLOQUEO] BIT NOT NULL,
# 	[FECHAC] DATETIME NULL,
# 	[FECHAM] DATETIME NULL,
# 	[Id_USUCRE] INTEGER NULL,
# 	[Id_USUMOD] INTEGER NULL,
# 	upsize_ts TIMESTAMP NULL,
# 	[STWF] INTEGER NOT NULL,
# 	[Id_REPRES] INTEGER NULL,
# 	[NIFE] NVARCHAR(20) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[NOAPLICA_IRPF] BIT NOT NULL,
# 	[REGIMEN_IVA] NVARCHAR(1) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[DIR_IP] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[NOAPLICA_RET_2] BIT NOT NULL,
# 	[NOAPLICA_RET_3] BIT NOT NULL,
# 	[NOAPLICA_RET_4] BIT NOT NULL,
# 	[MANDATO] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[MANDATO_FECHA] DATE NULL,
# 	[MANDATO_PERIODICIDAD] NVARCHAR(5) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[MANDATO_MARCA] BIT NULL,
# 	[MANDATO_FECHA_OP] DATETIME2 NULL,
# 	CONSTRAINT [PK_CLIENTE] PRIMARY KEY ([Id_CLIENTE])
# )
#
# /*
# 2 rows from CLIENTE table:
# Id_CLIENTE	Id_EMPRESA	CODCLI	Id_GRUCLI	Id_DIVISA	CIF	DENOMI	CONTACTO	DIRECC	CODPOS	LOCALIDAD	Id_PAIS	Id_PROVINCIA	GMT	TEL	TEL2	FAX	WWW	EMAIL1	EMAIL2	EMAIL3	SREFER	NREFER	Id_GRUPDOC	Id_CUENTA	Id_NATIVA	Id_FPAGO	Id_CONDIPAGO	Id_BANCO	SWIFT	IBAN	Id_DTO	Id_REC	LIMCRED	FACELEC	BLOQUEO	FECHAC	FECHAM	Id_USUCRE	Id_USUMOD	upsize_ts	STWF	Id_REPRES	NIFE	NOAPLICA_IRPF	REGIMEN_IVA	DIR_IP	NOAPLICA_RET_2	NOAPLICA_RET_3	NOAPLICA_RET_4	MANDATO	MANDATO_FECHA	MANDATO_PERIODICIDAD	MANDATO_MARCA	MANDATO_FECHA_OP
# 1	1	000001	1	46	A20005427	GRUPO MZ	D.Jesús Luengo	Polígono Lebario, Nº2 - Apartado 49	48220	Abadiano	65	20	1	943,82,16,00	None	None	None	jluengo@grupomz.com	None	None	None	None	1	992	4	11	4	None	None	None	None	None	0.00	False	False	2011-09-13 08:29:48.937000	None	1	None	b'\x00\x00\x00\x00\x00\x00\x07\xd1'	0	None	None	False	1	None	False	False	False	None	None	None	None	None
# 2	1	000002	1	46	A20000246	MANUFACTURAS PHILLIPS SCREW,SA	D. Luis Aguirrezabal	Polígono Industrial EITUA, nº63	48240	BERRIZ	65	48	1	None	None	None	None	luis@mafisa.com	None	None	None	None	1	993	4	4	4	None	None	None	None	None	0.00	False	False	2011-09-13 08:29:48.937000	None	1	None	b'\x00\x00\x00\x00\x00\x00\x07\xd2'	0	None	None	False	1	None	False	False	False	None	None	None	None	None
# */
#
#
# CREATE TABLE [T_EQUIPO] (
# 	[Id_EQUIPO] INTEGER NOT NULL IDENTITY(1,1),
# 	[Id_EMPRESA] INTEGER NOT NULL,
# 	[EQUIPO] NVARCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[DENOMI] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[TIPO] NVARCHAR(5) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FECHAC] DATETIME NULL,
# 	[FECHAM] DATETIME NULL,
# 	[Id_USUCRE] INTEGER NULL,
# 	[Id_USUMOD] INTEGER NULL,
# 	[DIVISION] NVARCHAR(3) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	upsize_ts TIMESTAMP NULL,
# 	[STWF] INTEGER NOT NULL,
# 	[Id_RESPONSABLE] INTEGER NULL,
# 	[Id_EQUIPOSUP] INTEGER NULL,
# 	[BLOQUEO] BIT NOT NULL,
# 	CONSTRAINT [PK_T_EQUIPOS] PRIMARY KEY ([Id_EQUIPO])
# )
#
# /*
# 2 rows from T_EQUIPO table:
# Id_EQUIPO	Id_EMPRESA	EQUIPO	DENOMI	TIPO	FECHAC	FECHAM	Id_USUCRE	Id_USUMOD	DIVISION	upsize_ts	STWF	Id_RESPONSABLE	Id_EQUIPOSUP	BLOQUEO
#
# */
#
#
# CREATE TABLE [T_FACTURA] (
# 	[Id_FACTURA] INTEGER NOT NULL IDENTITY(1,1),
# 	[Id_EMPRESA] INTEGER NOT NULL,
# 	[TIPOREG] VARCHAR(2) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[FACTURA] INTEGER NOT NULL,
# 	[FECHAF] DATE NOT NULL,
# 	[Id_CLIENTE] INTEGER NULL,
# 	[Id_PROVEEDOR] INTEGER NULL,
# 	[Id_CTA_PROVEE] INTEGER NULL,
# 	[CODTERCERO] NVARCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CIF] NVARCHAR(20) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_DIREC_FAC] INTEGER NULL,
# 	[DENOMI] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CONTACTO] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DIRECC] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CODPOS] NVARCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[LOCALIDAD] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_PROVINCIA] INTEGER NULL,
# 	[TEX_PROVINCIA] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_PAIS] INTEGER NULL,
# 	[TEX_PAIS] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_DIREC_ENV] INTEGER NULL,
# 	[DENOMI_ENV] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CONTACTO_ENV] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DIRECC_ENV] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CODPOS_ENV] NVARCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[LOCALIDAD_ENV] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_PROVINCIA_ENV] INTEGER NULL,
# 	[TEX_PROVINCIA_ENV] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_PAIS_ENV] INTEGER NULL,
# 	[TEX_PAIS_ENV] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_CATEGO] INTEGER NULL,
# 	[TERCERO2] VARCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[ESTADO] SMALLINT NOT NULL,
# 	[INTERFASE] SMALLINT NOT NULL,
# 	[Id_DIVISA] INTEGER NOT NULL,
# 	[CAMBIO] DECIMAL(18, 4) NOT NULL,
# 	[DECIMALES] INTEGER NOT NULL,
# 	[TOTMAT] DECIMAL(18, 4) NOT NULL,
# 	[IMPPORTES] DECIMAL(18, 4) NOT NULL,
# 	[IMPIRPF] DECIMAL(18, 4) NOT NULL,
# 	[TOTAL] DECIMAL(18, 4) NOT NULL,
# 	[FECHAREF] DATE NULL,
# 	[SFACTURA] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DIARIO] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[TEXTO] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[IMPRESION] SMALLINT NOT NULL,
# 	[Id_FPAGO] INTEGER NULL,
# 	[TEX_FPAGO] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_CONDIPAGO] INTEGER NULL,
# 	[TEX_CONDIPAGO] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[NPAGOS] SMALLINT NOT NULL,
# 	[DIAS1] SMALLINT NOT NULL,
# 	[CADENCIA] SMALLINT NOT NULL,
# 	[DFIJO1] SMALLINT NOT NULL,
# 	[DFIJO2] SMALLINT NOT NULL,
# 	[DFIJO3] SMALLINT NOT NULL,
# 	[VACAD] SMALLDATETIME NULL,
# 	[VACAH] SMALLDATETIME NULL,
# 	[DIAPAGOV1] SMALLDATETIME NULL,
# 	[DIAPAGOV2] SMALLDATETIME NULL,
# 	[INVOICE] SMALLINT NOT NULL,
# 	[Id_DOCUM_FAC] INTEGER NULL,
# 	[TEXTOC] TEXT(2147483647) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[TEXTOP] TEXT(2147483647) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[OBSERVA] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FECHAC] DATETIME NULL,
# 	[FECHAM] DATETIME NULL,
# 	[BLOQUEO] BIT NOT NULL,
# 	[Id_USUCRE] INTEGER NULL,
# 	[Id_USUMOD] INTEGER NULL,
# 	[DIVISION] NVARCHAR(3) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	upsize_ts TIMESTAMP NULL,
# 	[DOCUPATH] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[REPCOMPLIQ] NVARCHAR(1) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FECCOMLIQ] DATE NULL,
# 	[ABONO] SMALLINT NOT NULL,
# 	[FAC_ABO] INTEGER NOT NULL,
# 	[FECENV] DATE NULL,
# 	[VERSION] SMALLINT NOT NULL,
# 	[TERCERO3] VARCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[RTERCERO3] VARCHAR(70) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DTERCERO3] VARCHAR(70) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[Id_DTO] INTEGER NULL,
# 	[TEX_DTO] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[TASADTO] DECIMAL(18, 4) NOT NULL,
# 	[Id_REC] INTEGER NULL,
# 	[TEX_REC] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[TASAREC] DECIMAL(18, 4) NOT NULL,
# 	[DTOIMP] NVARCHAR(1) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DEFALBARAN] INTEGER NULL,
# 	[DEFNUMPED] INTEGER NULL,
# 	[Id_ASIENTO] INTEGER NULL,
# 	[TEX_PAIS_EMP] NCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CIF_EMP] NVARCHAR(20) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DATREGISTRO_EMP] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DATREGIVA_EMP] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[NOMFISCAL_EMP] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[DIRECC_EMP] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[CODPOS_EMP] NVARCHAR(10) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[LOCALIDAD_EMP] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[TEX_PROVINCIA_EMP] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[TEL_EMP] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[TEL2_EMP] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[FAX_EMP] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[WWW_EMP] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[EMAIL1_EMP] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[EMAIL2_EMP] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[EMAIL3_EMP] NVARCHAR(100) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[NCOPIAS] INTEGER NOT NULL,
# 	[R_DOCU] NVARCHAR(255) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[STWF] INTEGER NOT NULL,
# 	[IMPDTO] DECIMAL(18, 4) NOT NULL,
# 	[IMPGTO] DECIMAL(18, 4) NOT NULL,
# 	[IMPEMB] DECIMAL(18, 4) NOT NULL,
# 	[IMPIVA] DECIMAL(18, 4) NOT NULL,
# 	[IMPEQU] DECIMAL(18, 4) NOT NULL,
# 	[IMPSUP] DECIMAL(18, 4) NOT NULL,
# 	[REGIMEN_IVA] NVARCHAR(1) COLLATE SQL_Latin1_General_CP1_CI_AS NOT NULL,
# 	[DECIMALES_PRE] INTEGER NOT NULL,
# 	[Id_CONTRATO] INTEGER NULL,
# 	[TEX_TEX_FAC] NVARCHAR(200) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[IMPUESTO2] DECIMAL(18, 4) NOT NULL,
# 	[IMPUESTO3] DECIMAL(18, 4) NOT NULL,
# 	[IMPUESTO4] DECIMAL(18, 4) NOT NULL,
# 	[RETENCION2] DECIMAL(18, 4) NOT NULL,
# 	[RETENCION3] DECIMAL(18, 4) NOT NULL,
# 	[RETENCION4] DECIMAL(18, 4) NOT NULL,
# 	[TEX_IMP1] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[TEX_IMP2] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[TEX_IMP3] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[TEX_IMP4] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[TEX_RET1] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[TEX_RET2] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[TEX_RET3] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[TEX_RET4] NVARCHAR(50) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[SigFirma] NVARCHAR(500) COLLATE SQL_Latin1_General_CP1_CI_AS NULL,
# 	[TBAI] INTEGER NULL,
# 	[TBAIFLAG] SMALLINT NOT NULL,
# 	CONSTRAINT [PK_T_FACTURA] PRIMARY KEY ([Id_FACTURA]),
# 	CONSTRAINT [FK_T_FACTURAS_CLIENTE] FOREIGN KEY([Id_CLIENTE]) REFERENCES [CLIENTE] ([Id_CLIENTE])
# )
#
# /*
# 2 rows from T_FACTURA table:
# Id_FACTURA	Id_EMPRESA	TIPOREG	FACTURA	FECHAF	Id_CLIENTE	Id_PROVEEDOR	Id_CTA_PROVEE	CODTERCERO	CIF	Id_DIREC_FAC	DENOMI	CONTACTO	DIRECC	CODPOS	LOCALIDAD	Id_PROVINCIA	TEX_PROVINCIA	Id_PAIS	TEX_PAIS	Id_DIREC_ENV	DENOMI_ENV	CONTACTO_ENV	DIRECC_ENV	CODPOS_ENV	LOCALIDAD_ENV	Id_PROVINCIA_ENV	TEX_PROVINCIA_ENV	Id_PAIS_ENV	TEX_PAIS_ENV	Id_CATEGO	TERCERO2	ESTADO	INTERFASE	Id_DIVISA	CAMBIO	DECIMALES	TOTMAT	IMPPORTES	IMPIRPF	TOTAL	FECHAREF	SFACTURA	DIARIO	TEXTO	IMPRESION	Id_FPAGO	TEX_FPAGO	Id_CONDIPAGO	TEX_CONDIPAGO	NPAGOS	DIAS1	CADENCIA	DFIJO1	DFIJO2	DFIJO3	VACAD	VACAH	DIAPAGOV1	DIAPAGOV2	INVOICE	Id_DOCUM_FAC	TEXTOC	TEXTOP	OBSERVA	FECHAC	FECHAM	BLOQUEO	Id_USUCRE	Id_USUMOD	DIVISION	upsize_ts	DOCUPATH	REPCOMPLIQ	FECCOMLIQ	ABONO	FAC_ABO	FECENV	VERSION	TERCERO3	RTERCERO3	DTERCERO3	Id_DTO	TEX_DTO	TASADTO	Id_REC	TEX_REC	TASAREC	DTOIMP	DEFALBARAN	DEFNUMPED	Id_ASIENTO	TEX_PAIS_EMP	CIF_EMP	DATREGISTRO_EMP	DATREGIVA_EMP	NOMFISCAL_EMP	DIRECC_EMP	CODPOS_EMP	LOCALIDAD_EMP	TEX_PROVINCIA_EMP	TEL_EMP	TEL2_EMP	FAX_EMP	WWW_EMP	EMAIL1_EMP	EMAIL2_EMP	EMAIL3_EMP	NCOPIAS	R_DOCU	STWF	IMPDTO	IMPGTO	IMPEMB	IMPIVA	IMPEQU	IMPSUP	REGIMEN_IVA	DECIMALES_PRE	Id_CONTRATO	TEX_TEX_FAC	IMPUESTO2	IMPUESTO3	IMPUESTO4	RETENCION2	RETENCION3	RETENCION4	TEX_IMP1	TEX_IMP2	TEX_IMP3	TEX_IMP4	TEX_RET1	TEX_RET2	TEX_RET3	TEX_RET4	SigFirma	TBAI	TBAIFLAG
# 1521	1	FV	210216	2001-10-23	64	None	None	000064	A48035141	None	ELDU, S.A.	None	Carretera Bilbao - Galdácano, 11 BOLUETA	48004	BILBAO	48	Bizkaia	65	España	None	ELDU, S.A.	None	Carretera Bilbao - Galdácano, 11 BOLUETA	48004	BILBAO	48	Bizkaia	65	España	None	None	0	1	46	10000.0000	2	235000000.0000	0.0000	0.0000	272600000.0000	None	None	None	None	1	8	Letra aceptada	4	1 Pago a 15 dias. 1º-25	2	2	45	25	0	0	None	None	None	None	0	2	None	None	None	2011-09-14 11:07:37.470000	None	False	1	None	None	b'\x00\x00\x00\x00\x00\x00\x0c\xa6'	None	None	None	0	0	None	0	None	None	None	None	None	0.0000	None	None	0.0000	None	None	None	None	España    	B20511762	Reg. Merc. Gipuzkoa. Tomo 50 . Libro de Soc . Folio 100 . Asiento nº 1050	None	Gabinete de Gestión, S.L.	Parque Empresarial Zuatzu, C/Zuatzu 4, Pl.2ª-10	20018	San Sebastián	Gipuzkoa	943 31 69 63	None	943 31 73 04	www.evolution-tech.com	admin@evolution-tech.com	None	None	0	None	0	0.0000	0.0000	0.0000	37600000.0000	0.0000	0.0000	1	2	None	None	0.0000	0.0000	0.0000	0.0000	0.0000	0.0000	IVA Ventas	None	None	None	IRPF	None	None	None	None	None	0
# 1522	1	FV	210226	2001-10-31	64	None	None	000064	A48035141	None	ELDU, S.A.	None	Carretera Bilbao - Galdácano, 11 BOLUETA	48004	BILBAO	48	Bizkaia	65	España	None	ELDU, S.A.	None	Carretera Bilbao - Galdácano, 11 BOLUETA	48004	BILBAO	48	Bizkaia	65	España	None	None	0	1	46	10000.0000	2	38607300.0000	0.0000	0.0000	44784500.0000	None	None	None	None	1	11	Giros o Recibos	4	1 Pago a 15 dias. 1º-25	1	60	0	0	0	0	None	None	None	None	0	2	None	None	None	2011-09-14 11:07:37.473000	None	False	1	None	None	b'\x00\x00\x00\x00\x00\x00\x0c\xa7'	None	None	None	0	0	None	0	None	None	None	None	None	0.0000	None	None	0.0000	None	None	None	None	España    	B20511762	Reg. Merc. Gipuzkoa. Tomo 50 . Libro de Soc . Folio 100 . Asiento nº 1050	None	Gabinete de Gestión, S.L.	Parque Empresarial Zuatzu, C/Zuatzu 4, Pl.2ª-10	20018	San Sebastián	Gipuzkoa	943 31 69 63	None	943 31 73 04	www.evolution-tech.com	admin@evolution-tech.com	None	None	0	None	0	0.0000	0.0000	0.0000	6177200.0000	0.0000	0.0000	1	2	None	None	0.0000	0.0000	0.0000	0.0000	0.0000	0.0000	IVA Ventas	None	None	None	IRPF	None	None	None	None	None	0
# */

# %%
from langchain_community.agent_toolkits import create_sql_agent
from langchain.agents import AgentType

# %%
#agent_executor = create_sql_agent(llm, db = db, agent_type=AgentType.ZERO_SHOT_REACT_DESCRIPTION, verbose = True,stream_runnable=False,handle_parsing_errors=True)
#agent_executor = create_sql_agent(llm, db=db, agent_type="tool-calling", verbose=True, stream_runnable=False)
#agent_executor = create_sql_agent(llm, db = db, agent_type=AgentType.ZERO_SHOT_REACT_DESCRIPTION, verbose = True,handle_parsing_errors=True)
#agent_executor = create_sql_agent(llm, db = db, agent_type=AgentType.ZERO_SHOT_REACT_DESCRIPTION, verbose = True)
agent_executor = create_sql_agent(llm, db = db, agent_type=AgentType.ZERO_SHOT_REACT_DESCRIPTION, verbose = True, stream_runnable=False ,handle_parsing_errors=True)

# %%
#agent_executor.invoke("How many different Artists are in the database?")
#print(agent_executor.agent.runnable.get_prompts()[0].messages[0].content)
#agent_executor.invoke(q,handle_parsing_errors=True,include_run_info=True)
agent_executor.invoke(q)
#agent_executor.invoke("How many Artists are in the database?")
# Out:
# > Entering new SQL Agent Executor chain...
#  Tengo que saber si ELDU está dentro de algún nombre, entonces tendré que consultar la base de datos.
# Action: sql_db_query
# Action Input: select count(CustomerId) from Customers where CustomerName like "%ELDU%"Error: (pyodbc.ProgrammingError) ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Unclosed quotation mark after the character string '%ELDU%'. (105) (SQLExecDirectW); [42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near '%ELDU%'. (102)")
# [SQL: select count(CustomerId) from Customers where CustomerName like "%ELDU%]
# (Background on this error at: https://sqlalche.me/e/20/f405) ELDU está mal escrito, hay un espacio antes y despues de la palabra.
# Action: sql_db_query
# Action Input: select count(CustomerId) from Customers where CustomerName like "% ELDU %"Error: (pyodbc.ProgrammingError) ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Unclosed quotation mark after the character string '% ELDU %'. (105) (SQLExecDirectW); [42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near '% ELDU %'. (102)")
# [SQL: select count(CustomerId) from Customers where CustomerName like "% ELDU %]
# (Background on this error at: https://sqlalche.me/e/20/f405) Debería ser E%LDU%, no sé si hay otros errores también.
# Action: sql_db_query
# Action Input: select count(CustomerId) from Customers where CustomerName like "E%LDU%"Error: (pyodbc.ProgrammingError) ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Unclosed quotation mark after the character string 'E%LDU%'. (105) (SQLExecDirectW); [42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near 'E%LDU%'. (102)")
# [SQL: select count(CustomerId) from Customers where CustomerName like "E%LDU%]
# (Background on this error at: https://sqlalche.me/e/20/f405) No sé cómo resolver esto, debería consultar al experto.
# Action: sql_db_query_checker
# Action Input: select count(CustomerId) from Customers where CustomerName like "E%LDU%" select count(CustomerId) from Customers where CustomerName like "%E%LDU%";
# Correct SQL Query:  select count(CustomerId) from Customers where CustomerName like "%E%LDU%";
# SQL Query:  SELECT COUNT(*) FROM CUSTOMERS;
# Correct SQL Query:  SELECT COUNT(CUSTOMERID) FROM CUSTOMERS;
# SQL Query:  select count(CustomerId) from Customers where CustomerName like "E%LDU%";
# Correct SQL Query:  select count(CustomerId) from Customers where CustomerName like "%E%LDU%";
# SQL Query:  Select Count(CustomerId) From Customers Where CustomerName Like "%E%LDU%";
# Correct SQL Query:  select count(CustomerId) from Customers where CustomerName like "%E%LDU%";
# SQL Query:  SELECT COUNT(CUSTOMERID) FROM CUSTOMERS;
# Correct SQL Query:  SELECT COUNT(CUSTOMERID) FROM CUSTOMERS;
# SQL Query:  select count(CustomerId) from Customers where CustomerName not in ("%E%LDU%");
# Correct SQL Query:  select count(CustomerId) from Customers where CustomerName not like "%E%LDU%";
# SQL Query:  SELECT COUNT(CUSTOMERID) FROM CUSTOMERS;
# Correct SQL Query:  SELECT COUNT(CUSTOMERID) FROM CUSTOMERS;
# SQL Query:  Select Count(*) From Customers Where CustomerName Like "E%LDU%"
# Output: select count(CustomerId) from Customers where CustomerName like "%E%LDU%";
#
# SQL Query:  Select Count(CustomerId) From Customers Where CustomerName Like "E%LDU%";
# Output: select count(CustomerId) from Customers where CustomerName like "%E%LDU%";
#
# SQL Query:  SELECT COUNT(*) FROM CUSTOMERS;
# Output: select count(CustomerId) from Customers where CustomerName like "%E%LDU%";
#
# SQL Query:  Select Count(CustomerId) From Customers Where CustomerName Not Like "E%LDU%"
# Output: select count(CustomerId) from Customers where CustomerName not like "%E%LDU%";
#
# SQL Query:  SELECT COUNT(*) FROM CUSTOMERS;
# Output: select count(CustomerId) from Customers where CustomerName not like "%E%LDU%";
# <file_sep>select * from Employees order by birthdate desc limit 20;
#
# select firstname, lastname from employees where birthdate like '%-12-%' or birthdate like '%-01-%';
#
# select firstname, lastname, birthdate from employees order by birthdate asc limit 365;
#
# select firstname, lastname from employees where birthdate >= '1940-01-01' and birthdate <= '1949-12-31';
#
#
# select firstname, lastname from Employees where extract(year from BirthDate) > 1965 order by birthdate asc;
#
# select * from employees where extract(month from birthdate)= 12;
#
# SELECT firstname, lastname from employees where birthdate like '%-01-%' or birthdate like '%-03-%';
# <file_sep>select * from customers where customerid=698;
# select * from orders where orderid = 4557;
# select * from products where productid in (55,56);
#
# select firstname || " " || lastname as name, phone from employees where firstname='Thomas' or lastname='Hardy';
# select * from customers where city like 'Ber%' and country = 'Germany';
# select * from orders where shipcountry ='Brazil' and shippeddate is null;
# select * from orders where extract(year from orderdate) = 1997;
#  Tengo que saber si ELDU está dentro de algún nombre, entonces tendré que consultar la base de datos.
# Action: sql_db_query
# Action Input: select count(CustomerId) from Customers where CustomerName like "%ELDU%"Error: (pyodbc.ProgrammingError) ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Unclosed quotation mark after the character string '%ELDU%'. (105) (SQLExecDirectW); [42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near '%ELDU%'. (102)")
# [SQL: select count(CustomerId) from Customers where CustomerName like "%ELDU%]
# (Background on this error at: https://sqlalche.me/e/20/f405) No se porque da este error, debo checar la sintaxis de mi query, pero primero tengo que saber el significado de las comillas.
# Action: sql_db_query
# Action Input: select count(CustomerId) from Customers where CustomerName like "%ELDU%"Error: (pyodbc.ProgrammingError) ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Unclosed quotation mark after the character string '%ELDU%'. (105) (SQLExecDirectW); [42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near '%ELDU%'. (102)")
# [SQL: select count(CustomerId) from Customers where CustomerName like "%ELDU%]
# (Background on this error at: https://sqlalche.me/e/20/f405) Tengo que corregir la sintaxis del query
# Action: sql_db_query
# Action Input: select count(CustomerId) from Customers where CustomerName like "%ELDU%"Error: (pyodbc.ProgrammingError) ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Unclosed quotation mark after the character string '%ELDU%'. (105) (SQLExecDirectW); [42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near '%ELDU%'. (102)")
# [SQL: select count(CustomerId) from Customers where CustomerName like "%ELDU%]
# (Background on this error at: https://sqlalche.me/e/20/f405) Tengo que saber el significado de las comillas en los querys, porque son usadas para denotar un string.
# Action: sql_db_query
# Action Input: select count(CustomerId) from Customers where CustomerName like "%ELDU%"Error: (pyodbc.ProgrammingError) ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Unclosed quotation mark after the character string '%ELDU%'. (105) (SQLExecDirectW); [42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near '%ELDU%'. (102)")
# [SQL: select count(CustomerId) from Customers where CustomerName like "%ELDU%]
# (Background on this error at: https://sqlalche.me/e/20/f405) Tengo que corregir la sintaxis del query
# Action: sql_db_query
# Action Input: select count(CustomerId) from Customers where CustomerName like "%ELDU%"Error: (pyodbc.ProgrammingError) ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Unclosed quotation mark after the character string '%ELDU%'. (105) (SQLExecDirectW); [42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near '%ELDU%'. (102)")
# [SQL: select count(CustomerId) from Customers where CustomerName like "%ELDU%]
# (Background on this error at: https://sqlalche.me/e/20/f405) Tengo que corregir la sintaxis del query
# Action: sql_db_query
# Action Input: select count(CustomerId) from Customers where CustomerName like  "%ELDU%"Error: (pyodbc.ProgrammingError) ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Unclosed quotation mark after the character string '%ELDU%'. (105) (SQLExecDirectW); [42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near '%ELDU%'. (102)")
# [SQL: select count(CustomerId) from Customers where CustomerName like  "%ELDU%]
# (Background on this error at: https://sqlalche.me/e/20/f405) Tengo que saber el significado de las comillas en los querys, porque son usadas para denotar un string.
# Action: sql_db_query
# Action Input: select count(CustomerId) from Customers where CustomerName like "%ELDU%"Error: (pyodbc.ProgrammingError) ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Unclosed quotation mark after the character string '%ELDU%'. (105) (SQLExecDirectW); [42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near '%ELDU%'. (102)")
# [SQL: select count(CustomerId) from Customers where CustomerName like "%ELDU%]
# (Background on this error at: https://sqlalche.me/e/20/f405) Tengo que corregir la sintaxis del query
# Action: sql_db_query
# Action Input: select count(CustomerId) from Customers where CustomerName like   "%ELDU%"Error: (pyodbc.ProgrammingError) ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Unclosed quotation mark after the character string '%ELDU%'. (105) (SQLExecDirectW); [42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near '%ELDU%'. (102)")
# [SQL: select count(CustomerId) from Customers where CustomerName like   "%ELDU%]
# (Background on this error at: https://sqlalche.me/e/20/f405) Tengo que corregir la sintaxis del query, y tambien es necesario incluir el % en los querys.
# Action: sql_db_query
# Action Input: select count(CustomerId) from Customers where CustomerName like "%ELDU%"Error: (pyodbc.ProgrammingError) ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Unclosed quotation mark after the character string '%ELDU%'. (105) (SQLExecDirectW); [42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near '%ELDU%'. (102)")
# [SQL: select count(CustomerId) from Customers where CustomerName like "%ELDU%]
# (Background on this error at: https://sqlalche.me/e/20/f405) Tengo que corregir la sintaxis del query, y tambien es necesario incluir el % en los querys.
# Action: sql_db_query
# Action Input: select count(CustomerId) from Customers where CustomerName like "%ELDU%"Error: (pyodbc.ProgrammingError) ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Unclosed quotation mark after the character string '%ELDU%'. (105) (SQLExecDirectW); [42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]Incorrect syntax near '%ELDU%'. (102)")
# [SQL: select count(CustomerId) from Customers where CustomerName like "%ELDU%]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[36], line 4
#       1 #agent_executor.invoke("How many different Artists are in the database?")
#       2 #print(agent_executor.agent.runnable.get_prompts()[0].messages[0].content)
#       3 #agent_executor.invoke(q,handle_parsing_errors=True,include_run_info=True)
# ----> 4 agent_executor.invoke(q)
#       5 #agent_executor.invoke("How many Artists are in the database?")
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain\chains\base.py:166, in Chain.invoke(self, input, config, **kwargs)
#     164 except BaseException as e:
#     165     run_manager.on_chain_error(e)
# --> 166     raise e
#     167 run_manager.on_chain_end(outputs)
#     169 if include_run_info:
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain\chains\base.py:156, in Chain.invoke(self, input, config, **kwargs)
#     153 try:
#     154     self._validate_inputs(inputs)
#     155     outputs = (
# --> 156         self._call(inputs, run_manager=run_manager)
#     157         if new_arg_supported
#     158         else self._call(inputs)
#     159     )
#     161     final_outputs: Dict[str, Any] = self.prep_outputs(
#     162         inputs, outputs, return_only_outputs
#     163     )
#     164 except BaseException as e:
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain\agents\agent.py:1433, in AgentExecutor._call(self, inputs, run_manager)
#    1431 # We now enter the agent loop (until it returns something).
#    1432 while self._should_continue(iterations, time_elapsed):
# -> 1433     next_step_output = self._take_next_step(
#    1434         name_to_tool_map,
#    1435         color_mapping,
#    1436         inputs,
#    1437         intermediate_steps,
#    1438         run_manager=run_manager,
#    1439     )
#    1440     if isinstance(next_step_output, AgentFinish):
#    1441         return self._return(
#    1442             next_step_output, intermediate_steps, run_manager=run_manager
#    1443         )
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain\agents\agent.py:1139, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1130 def _take_next_step(
#    1131     self,
#    1132     name_to_tool_map: Dict[str, BaseTool],
#    (...)
#    1136     run_manager: Optional[CallbackManagerForChainRun] = None,
#    1137 ) -> Union[AgentFinish, List[Tuple[AgentAction, str]]]:
#    1138     return self._consume_next_step(
# -> 1139         [
#    1140             a
#    1141             for a in self._iter_next_step(
#    1142                 name_to_tool_map,
#    1143                 color_mapping,
#    1144                 inputs,
#    1145                 intermediate_steps,
#    1146                 run_manager,
#    1147             )
#    1148         ]
#    1149     )
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain\agents\agent.py:1167, in AgentExecutor._iter_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#    1164     intermediate_steps = self._prepare_intermediate_steps(intermediate_steps)
#    1166     # Call the LLM to see what to do.
# -> 1167     output = self.agent.plan(
#    1168         intermediate_steps,
#    1169         callbacks=run_manager.get_child() if run_manager else None,
#    1170         **inputs,
#    1171     )
#    1172 except OutputParserException as e:
#    1173     if isinstance(self.handle_parsing_errors, bool):
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain\agents\agent.py:404, in RunnableAgent.plan(self, intermediate_steps, callbacks, **kwargs)
#     402             final_output += chunk
#     403 else:
# --> 404     final_output = self.runnable.invoke(inputs, config={"callbacks": callbacks})
#     406 return final_output
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain_core\runnables\base.py:2507, in RunnableSequence.invoke(self, input, config, **kwargs)
#    2505             input = step.invoke(input, config, **kwargs)
#    2506         else:
# -> 2507             input = step.invoke(input, config)
#    2508 # finish the root run
#    2509 except BaseException as e:
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain_core\runnables\base.py:4588, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    4582 def invoke(
#    4583     self,
#    4584     input: Input,
#    4585     config: Optional[RunnableConfig] = None,
#    4586     **kwargs: Optional[Any],
#    4587 ) -> Output:
# -> 4588     return self.bound.invoke(
#    4589         input,
#    4590         self._merge_configs(config),
#    4591         **{**self.kwargs, **kwargs},
#    4592     )
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain_core\language_models\llms.py:276, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     266 def invoke(
#     267     self,
#     268     input: LanguageModelInput,
#    (...)
#     272     **kwargs: Any,
#     273 ) -> str:
#     274     config = ensure_config(config)
#     275     return (
# --> 276         self.generate_prompt(
#     277             [self._convert_input(input)],
#     278             stop=stop,
#     279             callbacks=config.get("callbacks"),
#     280             tags=config.get("tags"),
#     281             metadata=config.get("metadata"),
#     282             run_name=config.get("run_name"),
#     283             run_id=config.pop("run_id", None),
#     284             **kwargs,
#     285         )
#     286         .generations[0][0]
#     287         .text
#     288     )
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain_core\language_models\llms.py:633, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     625 def generate_prompt(
#     626     self,
#     627     prompts: List[PromptValue],
#    (...)
#     630     **kwargs: Any,
#     631 ) -> LLMResult:
#     632     prompt_strings = [p.to_string() for p in prompts]
# --> 633     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain_core\language_models\llms.py:803, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     788 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     789     run_managers = [
#     790         callback_manager.on_llm_start(
#     791             dumpd(self),
#    (...)
#     801         )
#     802     ]
# --> 803     output = self._generate_helper(
#     804         prompts, stop, run_managers, bool(new_arg_supported), **kwargs
#     805     )
#     806     return output
#     807 if len(missing_prompts) > 0:
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain_core\language_models\llms.py:670, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     668     for run_manager in run_managers:
#     669         run_manager.on_llm_error(e, response=LLMResult(generations=[]))
# --> 670     raise e
#     671 flattened_outputs = output.flatten()
#     672 for manager, flattened_output in zip(run_managers, flattened_outputs):
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain_core\language_models\llms.py:657, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     647 def _generate_helper(
#     648     self,
#     649     prompts: List[str],
#    (...)
#     653     **kwargs: Any,
#     654 ) -> LLMResult:
#     655     try:
#     656         output = (
# --> 657             self._generate(
#     658                 prompts,
#     659                 stop=stop,
#     660                 # TODO: support multiple run managers
#     661                 run_manager=run_managers[0] if run_managers else None,
#     662                 **kwargs,
#     663             )
#     664             if new_arg_supported
#     665             else self._generate(prompts, stop=stop)
#     666         )
#     667     except BaseException as e:
#     668         for run_manager in run_managers:
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain_community\llms\ollama.py:411, in Ollama._generate(self, prompts, stop, images, run_manager, **kwargs)
#     409 generations = []
#     410 for prompt in prompts:
# --> 411     final_chunk = super()._stream_with_aggregation(
#     412         prompt,
#     413         stop=stop,
#     414         images=images,
#     415         run_manager=run_manager,
#     416         verbose=self.verbose,
#     417         **kwargs,
#     418     )
#     419     generations.append([final_chunk])
#     420 return LLMResult(generations=generations)
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain_community\llms\ollama.py:327, in _OllamaCommon._stream_with_aggregation(self, prompt, stop, run_manager, verbose, **kwargs)
#     318 def _stream_with_aggregation(
#     319     self,
#     320     prompt: str,
#    (...)
#     324     **kwargs: Any,
#     325 ) -> GenerationChunk:
#     326     final_chunk: Optional[GenerationChunk] = None
# --> 327     for stream_resp in self._create_generate_stream(prompt, stop, **kwargs):
#     328         if stream_resp:
#     329             chunk = _stream_response_to_generation_chunk(stream_resp)
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\langchain_community\llms\ollama.py:174, in _OllamaCommon._create_generate_stream(self, prompt, stop, images, **kwargs)
#     166 def _create_generate_stream(
#     167     self,
#     168     prompt: str,
#    (...)
#     171     **kwargs: Any,
#     172 ) -> Iterator[str]:
#     173     payload = {"prompt": prompt, "images": images}
# --> 174     yield from self._create_stream(
#     175         payload=payload,
#     176         stop=stop,
#     177         api_url=f"{self.base_url}/api/generate",
#     178         **kwargs,
#     179     )
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\requests\models.py:869, in Response.iter_lines(self, chunk_size, decode_unicode, delimiter)
#     860 """Iterates over the response data, one line at a time.  When
#     861 stream=True is set on the request, this avoids reading the
#     862 content at once into memory for large responses.
#     863
#     864 .. note:: This method is not reentrant safe.
#     865 """
#     867 pending = None
# --> 869 for chunk in self.iter_content(
#     870     chunk_size=chunk_size, decode_unicode=decode_unicode
#     871 ):
#     872     if pending is not None:
#     873         chunk = pending + chunk
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\requests\utils.py:572, in stream_decode_response_unicode(iterator, r)
#     569     return
#     571 decoder = codecs.getincrementaldecoder(r.encoding)(errors="replace")
# --> 572 for chunk in iterator:
#     573     rv = decoder.decode(chunk)
#     574     if rv:
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\urllib3\response.py:1057, in HTTPResponse.stream(self, amt, decode_content)
#    1041 """
#    1042 A generator wrapper for the read() method. A call will block until
#    1043 ``amt`` bytes have been read from the connection or until the
#    (...)
#    1054     'content-encoding' header.
#    1055 """
#    1056 if self.chunked and self.supports_chunked_reads():
# -> 1057     yield from self.read_chunked(amt, decode_content=decode_content)
#    1058 else:
#    1059     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\urllib3\response.py:1206, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1203     amt = None
#    1205 while True:
# -> 1206     self._update_chunk_length()
#    1207     if self.chunk_left == 0:
#    1208         break
#
# File c:\Ia\iosub\IA\IA-Langchain-Agents\.venv\Lib\site-packages\urllib3\response.py:1125, in HTTPResponse._update_chunk_length(self)
#    1123 if self.chunk_left is not None:
#    1124     return None
# -> 1125 line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1126 line = line.split(b";", 1)[0]
#    1127 try:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# KeyboardInterrupt:
